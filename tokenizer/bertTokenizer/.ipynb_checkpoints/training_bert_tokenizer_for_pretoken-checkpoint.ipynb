# %%
from __future__ import print_function
from collections import defaultdict
import os
import sys
import posixpath

from elftools.elf.elffile import ELFFile

import os
import json 

import sys,os

# %%
special_tokens = ["[address]", "[mask]"]

# %%
DATA_PATH = "/home/raisul/ANALYSED_DATA/tokenization_data_single_functions"

json_files = [os.path.join(DATA_PATH, f) for f in os.listdir(DATA_PATH) ]

print(len(json_files))
print(json_files[0])
original = []
def read_corpus():

    all = []

    for k, j_file in enumerate(json_files):
        # if k>20:
        #     break
        try:
            with open(j_file, 'r') as file:
                funct_data = json.load( file )

                
                all.extend( [funct_data['disassembly_decimal'] , 
                             funct_data ['disassembly_all_number_to_words'] ,
                             funct_data ['disassembly_addresses_to_words']])
                original.append(  funct_data['disassembly_original'])
                original.append(  funct_data['disassembly_original'])
                original.append(  funct_data['disassembly_original'])
        except Exception as e:
            # Print the error message
            print(f"An error occurred: {e}")
    return all
    


training_corpus = read_corpus()



print("Functions Count: ",len(training_corpus), '\n')
example = training_corpus[10]
# Out:
# 87887
# /home/raisul/ANALYSED_DATA/tokenization_data_single_functions/4815315623712498727.json
# Functions Count:  263661

# %%
from transformers import AutoTokenizer

old_tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
old_tokenizer.pad_token
# Out:
# '[PAD]'

# %%
print(old_tokenizer.pad_token)
# Out:
# [PAD]

# %%
example = training_corpus[10]
print(example)
# Out:
# ENDBR64
# PUSH R12
# LEA RSI,[twelve]
# MOV EDI,zero
# PUSH RBP
# PUSH RBX
# SUB RSP,six
# MOV RAX,qword ptr FS:[seven]
# MOV qword ptr [RSP + five],RAX
# XOR EAX,EAX
# CALL nine
# LEA RCX,[RSP + three]
# LEA RDX,[RSP + two]
# XOR EAX,EAX
# LEA RSI,[RSP + one]
# LEA R8,[RSP + four]
# LEA RDI,[thirteen]
# CALL ten
# MOV EBX,dword ptr [RSP + four]
# MOV R12D,dword ptr [RSP + two]
# LEA RSI,[fifteen]
# MOV EBP,dword ptr [RSP + one]
# MOV EAX,dword ptr [RSP + three]
# MOV EDI,zero
# IMUL EBP,EBX
# IMUL EAX,R12D
# IMUL EBX,R12D
# ADD EBP,EAX
# XOR EAX,EAX
# CALL nine
# XOR EAX,EAX
# MOV ECX,EBX
# MOV EDX,EBP
# LEA RSI,[fourteen]
# MOV EDI,zero
# CALL nine
# MOV RAX,qword ptr [RSP + five]
# SUB RAX,qword ptr FS:[seven]
# JNZ eleven
# ADD RSP,six
# XOR EAX,EAX
# POP RBX
# POP RBP
# POP R12
# RET
# CALL eight

# %%
tokens = old_tokenizer.tokenize(example)
tokens
# Out:
# ['end',
#  '##br',
#  '##64',
#  'push',
#  'r',
#  '##12',
#  'lea',
#  'rs',
#  '##i',
#  ',',
#  '[',
#  'twelve',
#  ']',
#  'mo',
#  '##v',
#  'ed',
#  '##i',
#  ',',
#  'zero',
#  'push',
#  'rb',
#  '##p',
#  'push',
#  'rb',
#  '##x',
#  'sub',
#  'rs',
#  '##p',
#  ',',
#  'six',
#  'mo',
#  '##v',
#  'ra',
#  '##x',
#  ',',
#  'q',
#  '##word',
#  'pt',
#  '##r',
#  'f',
#  '##s',
#  ':',
#  '[',
#  'seven',
#  ']',
#  'mo',
#  '##v',
#  'q',
#  '##word',
#  'pt',
#  '##r',
#  '[',
#  'rs',
#  '##p',
#  '+',
#  'five',
#  ']',
#  ',',
#  'ra',
#  '##x',
#  'x',
#  '##or',
#  'ea',
#  '##x',
#  ',',
#  'ea',
#  '##x',
#  'call',
#  'nine',
#  'lea',
#  'rc',
#  '##x',
#  ',',
#  '[',
#  'rs',
#  '##p',
#  '+',
#  'three',
#  ']',
#  'lea',
#  'rd',
#  '##x',
#  ',',
#  '[',
#  'rs',
#  '##p',
#  '+',
#  'two',
#  ']',
#  'x',
#  '##or',
#  'ea',
#  '##x',
#  ',',
#  'ea',
#  '##x',
#  'lea',
#  'rs',
#  '##i',
#  ',',
#  '[',
#  'rs',
#  '##p',
#  '+',
#  'one',
#  ']',
#  'lea',
#  'r',
#  '##8',
#  ',',
#  '[',
#  'rs',
#  '##p',
#  '+',
#  'four',
#  ']',
#  'lea',
#  'rd',
#  '##i',
#  ',',
#  '[',
#  'thirteen',
#  ']',
#  'call',
#  'ten',
#  'mo',
#  '##v',
#  'e',
#  '##b',
#  '##x',
#  ',',
#  'd',
#  '##word',
#  'pt',
#  '##r',
#  '[',
#  'rs',
#  '##p',
#  '+',
#  'four',
#  ']',
#  'mo',
#  '##v',
#  'r',
#  '##12',
#  '##d',
#  ',',
#  'd',
#  '##word',
#  'pt',
#  '##r',
#  '[',
#  'rs',
#  '##p',
#  '+',
#  'two',
#  ']',
#  'lea',
#  'rs',
#  '##i',
#  ',',
#  '[',
#  'fifteen',
#  ']',
#  'mo',
#  '##v',
#  'e',
#  '##b',
#  '##p',
#  ',',
#  'd',
#  '##word',
#  'pt',
#  '##r',
#  '[',
#  'rs',
#  '##p',
#  '+',
#  'one',
#  ']',
#  'mo',
#  '##v',
#  'ea',
#  '##x',
#  ',',
#  'd',
#  '##word',
#  'pt',
#  '##r',
#  '[',
#  'rs',
#  '##p',
#  '+',
#  'three',
#  ']',
#  'mo',
#  '##v',
#  'ed',
#  '##i',
#  ',',
#  'zero',
#  'im',
#  '##ul',
#  'e',
#  '##b',
#  '##p',
#  ',',
#  'e',
#  '##b',
#  '##x',
#  'im',
#  '##ul',
#  'ea',
#  '##x',
#  ',',
#  'r',
#  '##12',
#  '##d',
#  'im',
#  '##ul',
#  'e',
#  '##b',
#  '##x',
#  ',',
#  'r',
#  '##12',
#  '##d',
#  'add',
#  'e',
#  '##b',
#  '##p',
#  ',',
#  'ea',
#  '##x',
#  'x',
#  '##or',
#  'ea',
#  '##x',
#  ',',
#  'ea',
#  '##x',
#  'call',
#  'nine',
#  'x',
#  '##or',
#  'ea',
#  '##x',
#  ',',
#  'ea',
#  '##x',
#  'mo',
#  '##v',
#  'ec',
#  '##x',
#  ',',
#  'e',
#  '##b',
#  '##x',
#  'mo',
#  '##v',
#  'ed',
#  '##x',
#  ',',
#  'e',
#  '##b',
#  '##p',
#  'lea',
#  'rs',
#  '##i',
#  ',',
#  '[',
#  'fourteen',
#  ']',
#  'mo',
#  '##v',
#  'ed',
#  '##i',
#  ',',
#  'zero',
#  'call',
#  'nine',
#  'mo',
#  '##v',
#  'ra',
#  '##x',
#  ',',
#  'q',
#  '##word',
#  'pt',
#  '##r',
#  '[',
#  'rs',
#  '##p',
#  '+',
#  'five',
#  ']',
#  'sub',
#  'ra',
#  '##x',
#  ',',
#  'q',
#  '##word',
#  'pt',
#  '##r',
#  'f',
#  '##s',
#  ':',
#  '[',
#  'seven',
#  ']',
#  'j',
#  '##nz',
#  'eleven',
#  'add',
#  'rs',
#  '##p',
#  ',',
#  'six',
#  'x',
#  '##or',
#  'ea',
#  '##x',
#  ',',
#  'ea',
#  '##x',
#  'pop',
#  'rb',
#  '##x',
#  'pop',
#  'rb',
#  '##p',
#  'pop',
#  'r',
#  '##12',
#  're',
#  '##t',
#  'call',
#  'eight']

# %%
tokenizer = old_tokenizer.train_new_from_iterator(training_corpus, vocab_size=200000, min_frequency=1 , additional_special_tokens = special_tokens )
# Out:
# Ignored unknown kwargs option additional_special_tokens

# %%
for i in range(100):
    tokens = tokenizer.tokenize(training_corpus[i])
    print(original[i])
    print(i%3,tokens)
# Out:
# ENDBR64
# TEST RDI,RDI
# JZ 0x00001488
# PUSH RBP
# LEA RBP,[0x2004]
# PUSH RBX
# MOV RBX,RDI
# SUB RSP,0x8
# NOP dword ptr [RAX]
# MOV ECX,dword ptr [RBX + 0x4]
# MOV EDX,dword ptr [RBX]
# MOV RSI,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x000010c0
# MOV RBX,qword ptr [RBX + 0x8]
# TEST RBX,RBX
# JNZ 0x00001460
# ADD RSP,0x8
# POP RBX
# POP RBP
# RET
# RET
#
# 0 ['endbr64', 'test', 'rdi', ',', 'rdi', 'jz', '5256', 'push', 'rbp', 'lea', 'rbp', ',', '[', '8196', ']', 'push', 'rbx', 'mov', 'rbx', ',', 'rdi', 'sub', 'rsp', ',', '8', 'nop', 'dword', 'ptr', '[', 'rax', ']', 'mov', 'ecx', ',', 'dword', 'ptr', '[', 'rbx', '+', '4', ']', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rbx', ']', 'mov', 'rsi', ',', 'rbp', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'call', '4288', 'mov', 'rbx', ',', 'qword', 'ptr', '[', 'rbx', '+', '8', ']', 'test', 'rbx', ',', 'rbx', 'jnz', '5216', 'add', 'rsp', ',', '8', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'ret']
# ENDBR64
# TEST RDI,RDI
# JZ 0x00001488
# PUSH RBP
# LEA RBP,[0x2004]
# PUSH RBX
# MOV RBX,RDI
# SUB RSP,0x8
# NOP dword ptr [RAX]
# MOV ECX,dword ptr [RBX + 0x4]
# MOV EDX,dword ptr [RBX]
# MOV RSI,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x000010c0
# MOV RBX,qword ptr [RBX + 0x8]
# TEST RBX,RBX
# JNZ 0x00001460
# ADD RSP,0x8
# POP RBX
# POP RBP
# RET
# RET
#
# 1 ['endbr64', 'test', 'rdi', ',', 'rdi', 'jz', 'five', 'push', 'rbp', 'lea', 'rbp', ',', '[', 'six', ']', 'push', 'rbx', 'mov', 'rbx', ',', 'rdi', 'sub', 'rsp', ',', 'two', 'nop', 'dword', 'ptr', '[', 'rax', ']', 'mov', 'ecx', ',', 'dword', 'ptr', '[', 'rbx', '+', 'one', ']', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rbx', ']', 'mov', 'rsi', ',', 'rbp', 'mov', 'edi', ',', 'zero', 'xor', 'eax', ',', 'eax', 'call', 'three', 'mov', 'rbx', ',', 'qword', 'ptr', '[', 'rbx', '+', 'two', ']', 'test', 'rbx', ',', 'rbx', 'jnz', 'four', 'add', 'rsp', ',', 'two', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'ret']
# ENDBR64
# TEST RDI,RDI
# JZ 0x00001488
# PUSH RBP
# LEA RBP,[0x2004]
# PUSH RBX
# MOV RBX,RDI
# SUB RSP,0x8
# NOP dword ptr [RAX]
# MOV ECX,dword ptr [RBX + 0x4]
# MOV EDX,dword ptr [RBX]
# MOV RSI,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x000010c0
# MOV RBX,qword ptr [RBX + 0x8]
# TEST RBX,RBX
# JNZ 0x00001460
# ADD RSP,0x8
# POP RBX
# POP RBP
# RET
# RET
#
# 2 ['endbr64', 'test', 'rdi', ',', 'rdi', 'jz', 'addr2', 'push', 'rbp', 'lea', 'rbp', ',', '[', '8196', ']', 'push', 'rbx', 'mov', 'rbx', ',', 'rdi', 'sub', 'rsp', ',', '8', 'nop', 'dword', 'ptr', '[', 'rax', ']', 'mov', 'ecx', ',', 'dword', 'ptr', '[', 'rbx', '+', '4', ']', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rbx', ']', 'mov', 'rsi', ',', 'rbp', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'call', 'addr0', 'mov', 'rbx', ',', 'qword', 'ptr', '[', 'rbx', '+', '8', ']', 'test', 'rbx', ',', 'rbx', 'jnz', 'addr1', 'add', 'rsp', ',', '8', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'ret']
# ENDBR64
# PUSH R12
# LEA RSI,[0x1200]
# MOV EDI,0x2
# LEA R12,[0x203d]
# PUSH RBP
# LEA RBP,[0x2046]
# PUSH RBX
# XOR EBX,EBX
# CALL 0x00001080
# JMP 0x000010e3
# MOV RDI,RBP
# ADD EBX,0x1
# CALL 0x00001070
# CMP EBX,0x2710
# JZ 0x00001100
# CMP EBX,0x64
# JNZ 0x000010d0
# MOV RDI,R12
# MOV EBX,0x65
# CALL 0x00001070
# MOV RDI,RBP
# CALL 0x00001070
# JMP 0x000010d0
# POP RBX
# XOR EAX,EAX
# POP RBP
# POP R12
# RET
#
# 0 ['endbr64', 'push', 'r12', 'lea', 'rsi', ',', '[', '4608', ']', 'mov', 'edi', ',', '2', 'lea', 'r12', ',', '[', '8253', ']', 'push', 'rbp', 'lea', 'rbp', ',', '[', '8262', ']', 'push', 'rbx', 'xor', 'ebx', ',', 'ebx', 'call', '4224', 'jmp', '4323', 'mov', 'rdi', ',', 'rbp', 'add', 'ebx', ',', '1', 'call', '4208', 'cmp', 'ebx', ',', '10000', 'jz', '4352', 'cmp', 'ebx', ',', '100', 'jnz', '4304', 'mov', 'rdi', ',', 'r12', 'mov', 'ebx', ',', '101', 'call', '4208', 'mov', 'rdi', ',', 'rbp', 'call', '4208', 'jmp', '4304', 'pop', 'rbx', 'xor', 'eax', ',', 'eax', 'pop', 'rbp', 'pop', 'r12', 'ret']
# ENDBR64
# PUSH R12
# LEA RSI,[0x1200]
# MOV EDI,0x2
# LEA R12,[0x203d]
# PUSH RBP
# LEA RBP,[0x2046]
# PUSH RBX
# XOR EBX,EBX
# CALL 0x00001080
# JMP 0x000010e3
# MOV RDI,RBP
# ADD EBX,0x1
# CALL 0x00001070
# CMP EBX,0x2710
# JZ 0x00001100
# CMP EBX,0x64
# JNZ 0x000010d0
# MOV RDI,R12
# MOV EBX,0x65
# CALL 0x00001070
# MOV RDI,RBP
# CALL 0x00001070
# JMP 0x000010d0
# POP RBX
# XOR EAX,EAX
# POP RBP
# POP R12
# RET
#
# 1 ['endbr64', 'push', 'r12', 'lea', 'rsi', ',', '[', 'nine', ']', 'mov', 'edi', ',', 'one', 'lea', 'r12', ',', '[', 'ten', ']', 'push', 'rbp', 'lea', 'rbp', ',', '[', 'eleven', ']', 'push', 'rbx', 'xor', 'ebx', ',', 'ebx', 'call', 'five', 'jmp', 'seven', 'mov', 'rdi', ',', 'rbp', 'add', 'ebx', ',', 'zero', 'call', 'four', 'cmp', 'ebx', ',', 'twelve', 'jz', 'eight', 'cmp', 'ebx', ',', 'two', 'jnz', 'six', 'mov', 'rdi', ',', 'r12', 'mov', 'ebx', ',', 'three', 'call', 'four', 'mov', 'rdi', ',', 'rbp', 'call', 'four', 'jmp', 'six', 'pop', 'rbx', 'xor', 'eax', ',', 'eax', 'pop', 'rbp', 'pop', 'r12', 'ret']
# ENDBR64
# PUSH R12
# LEA RSI,[0x1200]
# MOV EDI,0x2
# LEA R12,[0x203d]
# PUSH RBP
# LEA RBP,[0x2046]
# PUSH RBX
# XOR EBX,EBX
# CALL 0x00001080
# JMP 0x000010e3
# MOV RDI,RBP
# ADD EBX,0x1
# CALL 0x00001070
# CMP EBX,0x2710
# JZ 0x00001100
# CMP EBX,0x64
# JNZ 0x000010d0
# MOV RDI,R12
# MOV EBX,0x65
# CALL 0x00001070
# MOV RDI,RBP
# CALL 0x00001070
# JMP 0x000010d0
# POP RBX
# XOR EAX,EAX
# POP RBP
# POP R12
# RET
#
# 2 ['endbr64', 'push', 'r12', 'lea', 'rsi', ',', '[', '4608', ']', 'mov', 'edi', ',', '2', 'lea', 'r12', ',', '[', '8253', ']', 'push', 'rbp', 'lea', 'rbp', ',', '[', '8262', ']', 'push', 'rbx', 'xor', 'ebx', ',', 'ebx', 'call', 'addr1', 'jmp', 'addr3', 'mov', 'rdi', ',', 'rbp', 'add', 'ebx', ',', '1', 'call', 'addr0', 'cmp', 'ebx', ',', '10000', 'jz', 'addr4', 'cmp', 'ebx', ',', '100', 'jnz', 'addr2', 'mov', 'rdi', ',', 'r12', 'mov', 'ebx', ',', '101', 'call', 'addr0', 'mov', 'rdi', ',', 'rbp', 'call', 'addr0', 'jmp', 'addr2', 'pop', 'rbx', 'xor', 'eax', ',', 'eax', 'pop', 'rbp', 'pop', 'r12', 'ret']
# ENDBR64
# PXOR XMM2,XMM2
# CVTSI2SD XMM2,EDX
# UCOMISD XMM0,XMM2
# JP 0x00001364
# JZ 0x000013c8
# IMUL EAX,EDX,0x32
# PXOR XMM1,XMM1
# MOVAPD XMM4,XMM0
# SUBSD XMM4,XMM2
# PXOR XMM3,XMM3
# CVTSI2SD XMM3,ESI
# LEA ECX,[RDI + RAX*0x1]
# CVTSI2SD XMM1,ECX
# MULSD XMM1,XMM4
# COMISD XMM1,XMM3
# JNC 0x000013d0
# LEA EAX,[RAX + RDI*0x1 + 0x32]
# JMP 0x000013b5
# MOVAPD XMM1,XMM0
# SUBSD XMM1,XMM2
# PXOR XMM2,XMM2
# CVTSI2SD XMM2,EAX
# ADD EAX,0x32
# MULSD XMM1,XMM2
# COMISD XMM1,XMM3
# JNC 0x000013d0
# ADD EDX,0x1
# PXOR XMM2,XMM2
# CVTSI2SD XMM2,EDX
# UCOMISD XMM2,XMM0
# JP 0x00001398
# JNZ 0x00001398
# XOR EAX,EAX
# RET
# MOV EAX,0x1
# RET
#
# 0 ['endbr64', 'pxor', 'xmm2', ',', 'xmm2', 'cvtsi2sd', 'xmm2', ',', 'edx', 'ucomisd', 'xmm0', ',', 'xmm2', 'jp', '4964', 'jz', '5064', 'imul', 'eax', ',', 'edx', ',', '50', 'pxor', 'xmm1', ',', 'xmm1', 'movapd', 'xmm4', ',', 'xmm0', 'subsd', 'xmm4', ',', 'xmm2', 'pxor', 'xmm3', ',', 'xmm3', 'cvtsi2sd', 'xmm3', ',', 'esi', 'lea', 'ecx', ',', '[', 'rdi', '+', 'rax', '*', '1', ']', 'cvtsi2sd', 'xmm1', ',', 'ecx', 'mulsd', 'xmm1', ',', 'xmm4', 'comisd', 'xmm1', ',', 'xmm3', 'jnc', '5072', 'lea', 'eax', ',', '[', 'rax', '+', 'rdi', '*', '1', '+', '50', ']', 'jmp', '5045', 'movapd', 'xmm1', ',', 'xmm0', 'subsd', 'xmm1', ',', 'xmm2', 'pxor', 'xmm2', ',', 'xmm2', 'cvtsi2sd', 'xmm2', ',', 'eax', 'add', 'eax', ',', '50', 'mulsd', 'xmm1', ',', 'xmm2', 'comisd', 'xmm1', ',', 'xmm3', 'jnc', '5072', 'add', 'edx', ',', '1', 'pxor', 'xmm2', ',', 'xmm2', 'cvtsi2sd', 'xmm2', ',', 'edx', 'ucomisd', 'xmm2', ',', 'xmm0', 'jp', '5016', 'jnz', '5016', 'xor', 'eax', ',', 'eax', 'ret', 'mov', 'eax', ',', '1', 'ret']
# ENDBR64
# PXOR XMM2,XMM2
# CVTSI2SD XMM2,EDX
# UCOMISD XMM0,XMM2
# JP 0x00001364
# JZ 0x000013c8
# IMUL EAX,EDX,0x32
# PXOR XMM1,XMM1
# MOVAPD XMM4,XMM0
# SUBSD XMM4,XMM2
# PXOR XMM3,XMM3
# CVTSI2SD XMM3,ESI
# LEA ECX,[RDI + RAX*0x1]
# CVTSI2SD XMM1,ECX
# MULSD XMM1,XMM4
# COMISD XMM1,XMM3
# JNC 0x000013d0
# LEA EAX,[RAX + RDI*0x1 + 0x32]
# JMP 0x000013b5
# MOVAPD XMM1,XMM0
# SUBSD XMM1,XMM2
# PXOR XMM2,XMM2
# CVTSI2SD XMM2,EAX
# ADD EAX,0x32
# MULSD XMM1,XMM2
# COMISD XMM1,XMM3
# JNC 0x000013d0
# ADD EDX,0x1
# PXOR XMM2,XMM2
# CVTSI2SD XMM2,EDX
# UCOMISD XMM2,XMM0
# JP 0x00001398
# JNZ 0x00001398
# XOR EAX,EAX
# RET
# MOV EAX,0x1
# RET
#
# 1 ['endbr64', 'pxor', 'xmm2', ',', 'xmm2', 'cvtsi2sd', 'xmm2', ',', 'edx', 'ucomisd', 'xmm0', ',', 'xmm2', 'jp', 'two', 'jz', 'five', 'imul', 'eax', ',', 'edx', ',', 'one', 'pxor', 'xmm1', ',', 'xmm1', 'movapd', 'xmm4', ',', 'xmm0', 'subsd', 'xmm4', ',', 'xmm2', 'pxor', 'xmm3', ',', 'xmm3', 'cvtsi2sd', 'xmm3', ',', 'esi', 'lea', 'ecx', ',', '[', 'rdi', '+', 'rax', '*', 'zero', ']', 'cvtsi2sd', 'xmm1', ',', 'ecx', 'mulsd', 'xmm1', ',', 'xmm4', 'comisd', 'xmm1', ',', 'xmm3', 'jnc', 'six', 'lea', 'eax', ',', '[', 'rax', '+', 'rdi', '*', 'zero', '+', 'one', ']', 'jmp', 'four', 'movapd', 'xmm1', ',', 'xmm0', 'subsd', 'xmm1', ',', 'xmm2', 'pxor', 'xmm2', ',', 'xmm2', 'cvtsi2sd', 'xmm2', ',', 'eax', 'add', 'eax', ',', 'one', 'mulsd', 'xmm1', ',', 'xmm2', 'comisd', 'xmm1', ',', 'xmm3', 'jnc', 'six', 'add', 'edx', ',', 'zero', 'pxor', 'xmm2', ',', 'xmm2', 'cvtsi2sd', 'xmm2', ',', 'edx', 'ucomisd', 'xmm2', ',', 'xmm0', 'jp', 'three', 'jnz', 'three', 'xor', 'eax', ',', 'eax', 'ret', 'mov', 'eax', ',', 'zero', 'ret']
# ENDBR64
# PXOR XMM2,XMM2
# CVTSI2SD XMM2,EDX
# UCOMISD XMM0,XMM2
# JP 0x00001364
# JZ 0x000013c8
# IMUL EAX,EDX,0x32
# PXOR XMM1,XMM1
# MOVAPD XMM4,XMM0
# SUBSD XMM4,XMM2
# PXOR XMM3,XMM3
# CVTSI2SD XMM3,ESI
# LEA ECX,[RDI + RAX*0x1]
# CVTSI2SD XMM1,ECX
# MULSD XMM1,XMM4
# COMISD XMM1,XMM3
# JNC 0x000013d0
# LEA EAX,[RAX + RDI*0x1 + 0x32]
# JMP 0x000013b5
# MOVAPD XMM1,XMM0
# SUBSD XMM1,XMM2
# PXOR XMM2,XMM2
# CVTSI2SD XMM2,EAX
# ADD EAX,0x32
# MULSD XMM1,XMM2
# COMISD XMM1,XMM3
# JNC 0x000013d0
# ADD EDX,0x1
# PXOR XMM2,XMM2
# CVTSI2SD XMM2,EDX
# UCOMISD XMM2,XMM0
# JP 0x00001398
# JNZ 0x00001398
# XOR EAX,EAX
# RET
# MOV EAX,0x1
# RET
#
# 2 ['endbr64', 'pxor', 'xmm2', ',', 'xmm2', 'cvtsi2sd', 'xmm2', ',', 'edx', 'ucomisd', 'xmm0', ',', 'xmm2', 'jp', 'addr0', 'jz', 'addr3', 'imul', 'eax', ',', 'edx', ',', '50', 'pxor', 'xmm1', ',', 'xmm1', 'movapd', 'xmm4', ',', 'xmm0', 'subsd', 'xmm4', ',', 'xmm2', 'pxor', 'xmm3', ',', 'xmm3', 'cvtsi2sd', 'xmm3', ',', 'esi', 'lea', 'ecx', ',', '[', 'rdi', '+', 'rax', '*', '1', ']', 'cvtsi2sd', 'xmm1', ',', 'ecx', 'mulsd', 'xmm1', ',', 'xmm4', 'comisd', 'xmm1', ',', 'xmm3', 'jnc', 'addr4', 'lea', 'eax', ',', '[', 'rax', '+', 'rdi', '*', '1', '+', '50', ']', 'jmp', 'addr2', 'movapd', 'xmm1', ',', 'xmm0', 'subsd', 'xmm1', ',', 'xmm2', 'pxor', 'xmm2', ',', 'xmm2', 'cvtsi2sd', 'xmm2', ',', 'eax', 'add', 'eax', ',', '50', 'mulsd', 'xmm1', ',', 'xmm2', 'comisd', 'xmm1', ',', 'xmm3', 'jnc', 'addr4', 'add', 'edx', ',', '1', 'pxor', 'xmm2', ',', 'xmm2', 'cvtsi2sd', 'xmm2', ',', 'edx', 'ucomisd', 'xmm2', ',', 'xmm0', 'jp', 'addr1', 'jnz', 'addr1', 'xor', 'eax', ',', 'eax', 'ret', 'mov', 'eax', ',', '1', 'ret']
# ENDBR64
# PUSH R12
# LEA RSI,[0x2008]
# MOV EDI,0x2
# PUSH RBP
# PUSH RBX
# SUB RSP,0x20
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x18],RAX
# XOR EAX,EAX
# CALL 0x00001080
# LEA RCX,[RSP + 0x10]
# LEA RDX,[RSP + 0xc]
# XOR EAX,EAX
# LEA RSI,[RSP + 0x8]
# LEA R8,[RSP + 0x14]
# LEA RDI,[0x2036]
# CALL 0x00001090
# MOV EBX,dword ptr [RSP + 0x14]
# MOV R12D,dword ptr [RSP + 0xc]
# LEA RSI,[0x2042]
# MOV EBP,dword ptr [RSP + 0x8]
# MOV EAX,dword ptr [RSP + 0x10]
# MOV EDI,0x2
# IMUL EBP,EBX
# IMUL EAX,R12D
# IMUL EBX,R12D
# ADD EBP,EAX
# XOR EAX,EAX
# CALL 0x00001080
# XOR EAX,EAX
# MOV ECX,EBX
# MOV EDX,EBP
# LEA RSI,[0x203c]
# MOV EDI,0x2
# CALL 0x00001080
# MOV RAX,qword ptr [RSP + 0x18]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x00001152
# ADD RSP,0x20
# XOR EAX,EAX
# POP RBX
# POP RBP
# POP R12
# RET
# CALL 0x00001070
#
# 0 ['endbr64', 'push', 'r12', 'lea', 'rsi', ',', '[', '8200', ']', 'mov', 'edi', ',', '2', 'push', 'rbp', 'push', 'rbx', 'sub', 'rsp', ',', '32', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '24', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', '4224', 'lea', 'rcx', ',', '[', 'rsp', '+', '16', ']', 'lea', 'rdx', ',', '[', 'rsp', '+', '12', ']', 'xor', 'eax', ',', 'eax', 'lea', 'rsi', ',', '[', 'rsp', '+', '8', ']', 'lea', 'r8', ',', '[', 'rsp', '+', '20', ']', 'lea', 'rdi', ',', '[', '8246', ']', 'call', '4240', 'mov', 'ebx', ',', 'dword', 'ptr', '[', 'rsp', '+', '20', ']', 'mov', 'r12d', ',', 'dword', 'ptr', '[', 'rsp', '+', '12', ']', 'lea', 'rsi', ',', '[', '8258', ']', 'mov', 'ebp', ',', 'dword', 'ptr', '[', 'rsp', '+', '8', ']', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', '+', '16', ']', 'mov', 'edi', ',', '2', 'imul', 'ebp', ',', 'ebx', 'imul', 'eax', ',', 'r12d', 'imul', 'ebx', ',', 'r12d', 'add', 'ebp', ',', 'eax', 'xor', 'eax', ',', 'eax', 'call', '4224', 'xor', 'eax', ',', 'eax', 'mov', 'ecx', ',', 'ebx', 'mov', 'edx', ',', 'ebp', 'lea', 'rsi', ',', '[', '8252', ']', 'mov', 'edi', ',', '2', 'call', '4224', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '24', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', '4434', 'add', 'rsp', ',', '32', 'xor', 'eax', ',', 'eax', 'pop', 'rbx', 'pop', 'rbp', 'pop', 'r12', 'ret', 'call', '4208']
# ENDBR64
# PUSH R12
# LEA RSI,[0x2008]
# MOV EDI,0x2
# PUSH RBP
# PUSH RBX
# SUB RSP,0x20
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x18],RAX
# XOR EAX,EAX
# CALL 0x00001080
# LEA RCX,[RSP + 0x10]
# LEA RDX,[RSP + 0xc]
# XOR EAX,EAX
# LEA RSI,[RSP + 0x8]
# LEA R8,[RSP + 0x14]
# LEA RDI,[0x2036]
# CALL 0x00001090
# MOV EBX,dword ptr [RSP + 0x14]
# MOV R12D,dword ptr [RSP + 0xc]
# LEA RSI,[0x2042]
# MOV EBP,dword ptr [RSP + 0x8]
# MOV EAX,dword ptr [RSP + 0x10]
# MOV EDI,0x2
# IMUL EBP,EBX
# IMUL EAX,R12D
# IMUL EBX,R12D
# ADD EBP,EAX
# XOR EAX,EAX
# CALL 0x00001080
# XOR EAX,EAX
# MOV ECX,EBX
# MOV EDX,EBP
# LEA RSI,[0x203c]
# MOV EDI,0x2
# CALL 0x00001080
# MOV RAX,qword ptr [RSP + 0x18]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x00001152
# ADD RSP,0x20
# XOR EAX,EAX
# POP RBX
# POP RBP
# POP R12
# RET
# CALL 0x00001070
#
# 1 ['endbr64', 'push', 'r12', 'lea', 'rsi', ',', '[', 'twelve', ']', 'mov', 'edi', ',', 'zero', 'push', 'rbp', 'push', 'rbx', 'sub', 'rsp', ',', 'six', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'seven', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', 'five', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', 'nine', 'lea', 'rcx', ',', '[', 'rsp', '+', 'three', ']', 'lea', 'rdx', ',', '[', 'rsp', '+', 'two', ']', 'xor', 'eax', ',', 'eax', 'lea', 'rsi', ',', '[', 'rsp', '+', 'one', ']', 'lea', 'r8', ',', '[', 'rsp', '+', 'four', ']', 'lea', 'rdi', ',', '[', 'thirteen', ']', 'call', 'ten', 'mov', 'ebx', ',', 'dword', 'ptr', '[', 'rsp', '+', 'four', ']', 'mov', 'r12d', ',', 'dword', 'ptr', '[', 'rsp', '+', 'two', ']', 'lea', 'rsi', ',', '[', 'fifteen', ']', 'mov', 'ebp', ',', 'dword', 'ptr', '[', 'rsp', '+', 'one', ']', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', '+', 'three', ']', 'mov', 'edi', ',', 'zero', 'imul', 'ebp', ',', 'ebx', 'imul', 'eax', ',', 'r12d', 'imul', 'ebx', ',', 'r12d', 'add', 'ebp', ',', 'eax', 'xor', 'eax', ',', 'eax', 'call', 'nine', 'xor', 'eax', ',', 'eax', 'mov', 'ecx', ',', 'ebx', 'mov', 'edx', ',', 'ebp', 'lea', 'rsi', ',', '[', 'fourteen', ']', 'mov', 'edi', ',', 'zero', 'call', 'nine', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', 'five', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'seven', ']', 'jnz', 'eleven', 'add', 'rsp', ',', 'six', 'xor', 'eax', ',', 'eax', 'pop', 'rbx', 'pop', 'rbp', 'pop', 'r12', 'ret', 'call', 'eight']
# ENDBR64
# PUSH R12
# LEA RSI,[0x2008]
# MOV EDI,0x2
# PUSH RBP
# PUSH RBX
# SUB RSP,0x20
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x18],RAX
# XOR EAX,EAX
# CALL 0x00001080
# LEA RCX,[RSP + 0x10]
# LEA RDX,[RSP + 0xc]
# XOR EAX,EAX
# LEA RSI,[RSP + 0x8]
# LEA R8,[RSP + 0x14]
# LEA RDI,[0x2036]
# CALL 0x00001090
# MOV EBX,dword ptr [RSP + 0x14]
# MOV R12D,dword ptr [RSP + 0xc]
# LEA RSI,[0x2042]
# MOV EBP,dword ptr [RSP + 0x8]
# MOV EAX,dword ptr [RSP + 0x10]
# MOV EDI,0x2
# IMUL EBP,EBX
# IMUL EAX,R12D
# IMUL EBX,R12D
# ADD EBP,EAX
# XOR EAX,EAX
# CALL 0x00001080
# XOR EAX,EAX
# MOV ECX,EBX
# MOV EDX,EBP
# LEA RSI,[0x203c]
# MOV EDI,0x2
# CALL 0x00001080
# MOV RAX,qword ptr [RSP + 0x18]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x00001152
# ADD RSP,0x20
# XOR EAX,EAX
# POP RBX
# POP RBP
# POP R12
# RET
# CALL 0x00001070
#
# 2 ['endbr64', 'push', 'r12', 'lea', 'rsi', ',', '[', '8200', ']', 'mov', 'edi', ',', '2', 'push', 'rbp', 'push', 'rbx', 'sub', 'rsp', ',', '32', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '24', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', 'addr1', 'lea', 'rcx', ',', '[', 'rsp', '+', '16', ']', 'lea', 'rdx', ',', '[', 'rsp', '+', '12', ']', 'xor', 'eax', ',', 'eax', 'lea', 'rsi', ',', '[', 'rsp', '+', '8', ']', 'lea', 'r8', ',', '[', 'rsp', '+', '20', ']', 'lea', 'rdi', ',', '[', '8246', ']', 'call', 'addr2', 'mov', 'ebx', ',', 'dword', 'ptr', '[', 'rsp', '+', '20', ']', 'mov', 'r12d', ',', 'dword', 'ptr', '[', 'rsp', '+', '12', ']', 'lea', 'rsi', ',', '[', '8258', ']', 'mov', 'ebp', ',', 'dword', 'ptr', '[', 'rsp', '+', '8', ']', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', '+', '16', ']', 'mov', 'edi', ',', '2', 'imul', 'ebp', ',', 'ebx', 'imul', 'eax', ',', 'r12d', 'imul', 'ebx', ',', 'r12d', 'add', 'ebp', ',', 'eax', 'xor', 'eax', ',', 'eax', 'call', 'addr1', 'xor', 'eax', ',', 'eax', 'mov', 'ecx', ',', 'ebx', 'mov', 'edx', ',', 'ebp', 'lea', 'rsi', ',', '[', '8252', ']', 'mov', 'edi', ',', '2', 'call', 'addr1', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '24', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', 'addr3', 'add', 'rsp', ',', '32', 'xor', 'eax', ',', 'eax', 'pop', 'rbx', 'pop', 'rbp', 'pop', 'r12', 'ret', 'call', 'addr0']
# ENDBR64
# MOV EAX,dword ptr [0x00004040]
# LEA RCX,[0x4060]
# LEA EDX,[RAX + 0x1]
# ADD EAX,0x2
# MOVSXD RSI,EDX
# MOV dword ptr [0x00004040],EDX
# MOV dword ptr [RCX + RSI*0x4],EDI
# CMP EAX,0x2
# JA 0x000012e7
# RET
# MOVSXD RDX,EDX
# MOV dword ptr [RCX + RSI*0x4],EDI
# MOV dword ptr [RCX + RDX*0x4],R8D
# LEA EDX,[RAX + 0x1]
# CMP EDX,0x2
# JBE 0x000012fc
# MOV EDI,dword ptr [RCX + RSI*0x4]
# MOV EDX,EAX
# MOV EAX,EDX
# SHR EAX,0x1f
# ADD EAX,EDX
# SAR EAX,0x1
# MOVSXD RSI,EAX
# MOV R8D,dword ptr [RCX + RSI*0x4]
# CMP R8D,EDI
# JL 0x000012d0
# RET
#
# 0 ['endbr64', 'mov', 'eax', ',', 'dword', 'ptr', '[', '16448', ']', 'lea', 'rcx', ',', '[', '16480', ']', 'lea', 'edx', ',', '[', 'rax', '+', '1', ']', 'add', 'eax', ',', '2', 'movsxd', 'rsi', ',', 'edx', 'mov', 'dword', 'ptr', '[', '16448', ']', ',', 'edx', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', '4', ']', ',', 'edi', 'cmp', 'eax', ',', '2', 'ja', '4839', 'ret', 'movsxd', 'rdx', ',', 'edx', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', '4', ']', ',', 'edi', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rdx', '*', '4', ']', ',', 'r8d', 'lea', 'edx', ',', '[', 'rax', '+', '1', ']', 'cmp', 'edx', ',', '2', 'jbe', '4860', 'mov', 'edi', ',', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', '4', ']', 'mov', 'edx', ',', 'eax', 'mov', 'eax', ',', 'edx', 'shr', 'eax', ',', '31', 'add', 'eax', ',', 'edx', 'sar', 'eax', ',', '1', 'movsxd', 'rsi', ',', 'eax', 'mov', 'r8d', ',', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', '4', ']', 'cmp', 'r8d', ',', 'edi', 'jl', '4816', 'ret']
# ENDBR64
# MOV EAX,dword ptr [0x00004040]
# LEA RCX,[0x4060]
# LEA EDX,[RAX + 0x1]
# ADD EAX,0x2
# MOVSXD RSI,EDX
# MOV dword ptr [0x00004040],EDX
# MOV dword ptr [RCX + RSI*0x4],EDI
# CMP EAX,0x2
# JA 0x000012e7
# RET
# MOVSXD RDX,EDX
# MOV dword ptr [RCX + RSI*0x4],EDI
# MOV dword ptr [RCX + RDX*0x4],R8D
# LEA EDX,[RAX + 0x1]
# CMP EDX,0x2
# JBE 0x000012fc
# MOV EDI,dword ptr [RCX + RSI*0x4]
# MOV EDX,EAX
# MOV EAX,EDX
# SHR EAX,0x1f
# ADD EAX,EDX
# SAR EAX,0x1
# MOVSXD RSI,EAX
# MOV R8D,dword ptr [RCX + RSI*0x4]
# CMP R8D,EDI
# JL 0x000012d0
# RET
#
# 1 ['endbr64', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'seven', ']', 'lea', 'rcx', ',', '[', 'eight', ']', 'lea', 'edx', ',', '[', 'rax', '+', 'zero', ']', 'add', 'eax', ',', 'one', 'movsxd', 'rsi', ',', 'edx', 'mov', 'dword', 'ptr', '[', 'seven', ']', ',', 'edx', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', 'two', ']', ',', 'edi', 'cmp', 'eax', ',', 'one', 'ja', 'five', 'ret', 'movsxd', 'rdx', ',', 'edx', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', 'two', ']', ',', 'edi', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rdx', '*', 'two', ']', ',', 'r8d', 'lea', 'edx', ',', '[', 'rax', '+', 'zero', ']', 'cmp', 'edx', ',', 'one', 'jbe', 'six', 'mov', 'edi', ',', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', 'two', ']', 'mov', 'edx', ',', 'eax', 'mov', 'eax', ',', 'edx', 'shr', 'eax', ',', 'three', 'add', 'eax', ',', 'edx', 'sar', 'eax', ',', 'zero', 'movsxd', 'rsi', ',', 'eax', 'mov', 'r8d', ',', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', 'two', ']', 'cmp', 'r8d', ',', 'edi', 'jl', 'four', 'ret']
# ENDBR64
# MOV EAX,dword ptr [0x00004040]
# LEA RCX,[0x4060]
# LEA EDX,[RAX + 0x1]
# ADD EAX,0x2
# MOVSXD RSI,EDX
# MOV dword ptr [0x00004040],EDX
# MOV dword ptr [RCX + RSI*0x4],EDI
# CMP EAX,0x2
# JA 0x000012e7
# RET
# MOVSXD RDX,EDX
# MOV dword ptr [RCX + RSI*0x4],EDI
# MOV dword ptr [RCX + RDX*0x4],R8D
# LEA EDX,[RAX + 0x1]
# CMP EDX,0x2
# JBE 0x000012fc
# MOV EDI,dword ptr [RCX + RSI*0x4]
# MOV EDX,EAX
# MOV EAX,EDX
# SHR EAX,0x1f
# ADD EAX,EDX
# SAR EAX,0x1
# MOVSXD RSI,EAX
# MOV R8D,dword ptr [RCX + RSI*0x4]
# CMP R8D,EDI
# JL 0x000012d0
# RET
#
# 2 ['endbr64', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'addr3', ']', 'lea', 'rcx', ',', '[', '16480', ']', 'lea', 'edx', ',', '[', 'rax', '+', '1', ']', 'add', 'eax', ',', '2', 'movsxd', 'rsi', ',', 'edx', 'mov', 'dword', 'ptr', '[', 'addr3', ']', ',', 'edx', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', '4', ']', ',', 'edi', 'cmp', 'eax', ',', '2', 'ja', 'addr1', 'ret', 'movsxd', 'rdx', ',', 'edx', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', '4', ']', ',', 'edi', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rdx', '*', '4', ']', ',', 'r8d', 'lea', 'edx', ',', '[', 'rax', '+', '1', ']', 'cmp', 'edx', ',', '2', 'jbe', 'addr2', 'mov', 'edi', ',', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', '4', ']', 'mov', 'edx', ',', 'eax', 'mov', 'eax', ',', 'edx', 'shr', 'eax', ',', '31', 'add', 'eax', ',', 'edx', 'sar', 'eax', ',', '1', 'movsxd', 'rsi', ',', 'eax', 'mov', 'r8d', ',', 'dword', 'ptr', '[', 'rcx', '+', 'rsi', '*', '4', ']', 'cmp', 'r8d', ',', 'edi', 'jl', 'addr0', 'ret']
# ENDBR64
# SUB RSP,0x28
# LEA RSI,[0x2004]
# MOV EDI,0x2
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x18],RAX
# XOR EAX,EAX
# CALL 0x000010a0
# XOR EAX,EAX
# MOV RSI,RSP
# LEA RDI,[0x2017]
# CALL 0x000010b0
# CMP byte ptr [RSP],0x0
# JZ 0x00001137
# LEA RDI,[RSP + 0x1]
# CALL 0x00001080
# LEA EDX,[RAX + 0x1]
# XOR EAX,EAX
# LEA RSI,[0x2020]
# MOV EDI,0x2
# CALL 0x000010a0
# MOV RAX,qword ptr [RSP + 0x18]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x0000113b
# XOR EAX,EAX
# ADD RSP,0x28
# RET
# XOR EDX,EDX
# JMP 0x0000110d
# CALL 0x00001090
#
# 0 ['endbr64', 'sub', 'rsp', ',', '40', 'lea', 'rsi', ',', '[', '8196', ']', 'mov', 'edi', ',', '2', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '24', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', '4256', 'xor', 'eax', ',', 'eax', 'mov', 'rsi', ',', 'rsp', 'lea', 'rdi', ',', '[', '8215', ']', 'call', '4272', 'cmp', 'byte', 'ptr', '[', 'rsp', ']', ',', '0', 'jz', '4407', 'lea', 'rdi', ',', '[', 'rsp', '+', '1', ']', 'call', '4224', 'lea', 'edx', ',', '[', 'rax', '+', '1', ']', 'xor', 'eax', ',', 'eax', 'lea', 'rsi', ',', '[', '8224', ']', 'mov', 'edi', ',', '2', 'call', '4256', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '24', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', '4411', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', '40', 'ret', 'xor', 'edx', ',', 'edx', 'jmp', '4365', 'call', '4240']
# ENDBR64
# SUB RSP,0x28
# LEA RSI,[0x2004]
# MOV EDI,0x2
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x18],RAX
# XOR EAX,EAX
# CALL 0x000010a0
# XOR EAX,EAX
# MOV RSI,RSP
# LEA RDI,[0x2017]
# CALL 0x000010b0
# CMP byte ptr [RSP],0x0
# JZ 0x00001137
# LEA RDI,[RSP + 0x1]
# CALL 0x00001080
# LEA EDX,[RAX + 0x1]
# XOR EAX,EAX
# LEA RSI,[0x2020]
# MOV EDI,0x2
# CALL 0x000010a0
# MOV RAX,qword ptr [RSP + 0x18]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x0000113b
# XOR EAX,EAX
# ADD RSP,0x28
# RET
# XOR EDX,EDX
# JMP 0x0000110d
# CALL 0x00001090
#
# 1 ['endbr64', 'sub', 'rsp', ',', 'four', 'lea', 'rsi', ',', '[', 'twelve', ']', 'mov', 'edi', ',', 'two', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'four', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', 'three', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', 'seven', 'xor', 'eax', ',', 'eax', 'mov', 'rsi', ',', 'rsp', 'lea', 'rdi', ',', '[', 'thirteen', ']', 'call', 'eight', 'cmp', 'byte', 'ptr', '[', 'rsp', ']', ',', 'zero', 'jz', 'ten', 'lea', 'rdi', ',', '[', 'rsp', '+', 'one', ']', 'call', 'five', 'lea', 'edx', ',', '[', 'rax', '+', 'one', ']', 'xor', 'eax', ',', 'eax', 'lea', 'rsi', ',', '[', 'fourteen', ']', 'mov', 'edi', ',', 'two', 'call', 'seven', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', 'three', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'four', ']', 'jnz', 'eleven', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', 'four', 'ret', 'xor', 'edx', ',', 'edx', 'jmp', 'nine', 'call', 'six']
# ENDBR64
# SUB RSP,0x28
# LEA RSI,[0x2004]
# MOV EDI,0x2
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x18],RAX
# XOR EAX,EAX
# CALL 0x000010a0
# XOR EAX,EAX
# MOV RSI,RSP
# LEA RDI,[0x2017]
# CALL 0x000010b0
# CMP byte ptr [RSP],0x0
# JZ 0x00001137
# LEA RDI,[RSP + 0x1]
# CALL 0x00001080
# LEA EDX,[RAX + 0x1]
# XOR EAX,EAX
# LEA RSI,[0x2020]
# MOV EDI,0x2
# CALL 0x000010a0
# MOV RAX,qword ptr [RSP + 0x18]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x0000113b
# XOR EAX,EAX
# ADD RSP,0x28
# RET
# XOR EDX,EDX
# JMP 0x0000110d
# CALL 0x00001090
#
# 2 ['endbr64', 'sub', 'rsp', ',', '40', 'lea', 'rsi', ',', '[', '8196', ']', 'mov', 'edi', ',', '2', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '24', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', 'addr2', 'xor', 'eax', ',', 'eax', 'mov', 'rsi', ',', 'rsp', 'lea', 'rdi', ',', '[', '8215', ']', 'call', 'addr3', 'cmp', 'byte', 'ptr', '[', 'rsp', ']', ',', '0', 'jz', 'addr5', 'lea', 'rdi', ',', '[', 'rsp', '+', '1', ']', 'call', 'addr0', 'lea', 'edx', ',', '[', 'rax', '+', '1', ']', 'xor', 'eax', ',', 'eax', 'lea', 'rsi', ',', '[', '8224', ']', 'mov', 'edi', ',', '2', 'call', 'addr2', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '24', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', 'addr6', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', '40', 'ret', 'xor', 'edx', ',', 'edx', 'jmp', 'addr4', 'call', 'addr1']
# ENDBR64
# PUSH RBP
# LEA RBP,[0x2027]
# XOR EAX,EAX
# MOV ESI,0x2
# PUSH RBX
# MOV RDI,RBP
# SUB RSP,0x8
# CALL 0x00001120
# TEST EAX,EAX
# JS 0x00001193
# MOV EBX,EAX
# MOV RDX,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# LEA RSI,[0x204b]
# CALL 0x00001110
# MOV EDI,EBX
# CALL 0x000012b0
# MOV EDI,EBX
# CALL 0x00001100
# XOR EAX,EAX
# ADD RSP,0x8
# POP RBX
# POP RBP
# RET
# CALL 0x000010c0
# MOV EDI,dword ptr [RAX]
# CALL 0x00001130
# LEA RSI,[0x203d]
# MOV EDI,0x2
# MOV RDX,RAX
# XOR EAX,EAX
# CALL 0x00001110
# OR EAX,0xffffffff
# JMP 0x0000118c
#
# 0 ['endbr64', 'push', 'rbp', 'lea', 'rbp', ',', '[', '8231', ']', 'xor', 'eax', ',', 'eax', 'mov', 'esi', ',', '2', 'push', 'rbx', 'mov', 'rdi', ',', 'rbp', 'sub', 'rsp', ',', '8', 'call', '4384', 'test', 'eax', ',', 'eax', 'js', '4499', 'mov', 'ebx', ',', 'eax', 'mov', 'rdx', ',', 'rbp', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'lea', 'rsi', ',', '[', '8267', ']', 'call', '4368', 'mov', 'edi', ',', 'ebx', 'call', '4784', 'mov', 'edi', ',', 'ebx', 'call', '4352', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', '8', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'call', '4288', 'mov', 'edi', ',', 'dword', 'ptr', '[', 'rax', ']', 'call', '4400', 'lea', 'rsi', ',', '[', '8253', ']', 'mov', 'edi', ',', '2', 'mov', 'rdx', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', '4368', 'or', 'eax', ',', '4294967295', 'jmp', '4492']
# ENDBR64
# PUSH RBP
# LEA RBP,[0x2027]
# XOR EAX,EAX
# MOV ESI,0x2
# PUSH RBX
# MOV RDI,RBP
# SUB RSP,0x8
# CALL 0x00001120
# TEST EAX,EAX
# JS 0x00001193
# MOV EBX,EAX
# MOV RDX,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# LEA RSI,[0x204b]
# CALL 0x00001110
# MOV EDI,EBX
# CALL 0x000012b0
# MOV EDI,EBX
# CALL 0x00001100
# XOR EAX,EAX
# ADD RSP,0x8
# POP RBX
# POP RBP
# RET
# CALL 0x000010c0
# MOV EDI,dword ptr [RAX]
# CALL 0x00001130
# LEA RSI,[0x203d]
# MOV EDI,0x2
# MOV RDX,RAX
# XOR EAX,EAX
# CALL 0x00001110
# OR EAX,0xffffffff
# JMP 0x0000118c
#
# 1 ['endbr64', 'push', 'rbp', 'lea', 'rbp', ',', '[', 'ten', ']', 'xor', 'eax', ',', 'eax', 'mov', 'esi', ',', 'zero', 'push', 'rbx', 'mov', 'rdi', ',', 'rbp', 'sub', 'rsp', ',', 'one', 'call', 'five', 'test', 'eax', ',', 'eax', 'js', 'eight', 'mov', 'ebx', ',', 'eax', 'mov', 'rdx', ',', 'rbp', 'mov', 'edi', ',', 'zero', 'xor', 'eax', ',', 'eax', 'lea', 'rsi', ',', '[', 'twelve', ']', 'call', 'four', 'mov', 'edi', ',', 'ebx', 'call', 'nine', 'mov', 'edi', ',', 'ebx', 'call', 'three', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', 'one', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'call', 'two', 'mov', 'edi', ',', 'dword', 'ptr', '[', 'rax', ']', 'call', 'six', 'lea', 'rsi', ',', '[', 'eleven', ']', 'mov', 'edi', ',', 'zero', 'mov', 'rdx', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', 'four', 'or', 'eax', ',', 'thirteen', 'jmp', 'seven']
# ENDBR64
# PUSH RBP
# LEA RBP,[0x2027]
# XOR EAX,EAX
# MOV ESI,0x2
# PUSH RBX
# MOV RDI,RBP
# SUB RSP,0x8
# CALL 0x00001120
# TEST EAX,EAX
# JS 0x00001193
# MOV EBX,EAX
# MOV RDX,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# LEA RSI,[0x204b]
# CALL 0x00001110
# MOV EDI,EBX
# CALL 0x000012b0
# MOV EDI,EBX
# CALL 0x00001100
# XOR EAX,EAX
# ADD RSP,0x8
# POP RBX
# POP RBP
# RET
# CALL 0x000010c0
# MOV EDI,dword ptr [RAX]
# CALL 0x00001130
# LEA RSI,[0x203d]
# MOV EDI,0x2
# MOV RDX,RAX
# XOR EAX,EAX
# CALL 0x00001110
# OR EAX,0xffffffff
# JMP 0x0000118c
#
# 2 ['endbr64', 'push', 'rbp', 'lea', 'rbp', ',', '[', '8231', ']', 'xor', 'eax', ',', 'eax', 'mov', 'esi', ',', '2', 'push', 'rbx', 'mov', 'rdi', ',', 'rbp', 'sub', 'rsp', ',', '8', 'call', 'addr3', 'test', 'eax', ',', 'eax', 'js', 'addr6', 'mov', 'ebx', ',', 'eax', 'mov', 'rdx', ',', 'rbp', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'lea', 'rsi', ',', '[', '8267', ']', 'call', 'addr2', 'mov', 'edi', ',', 'ebx', 'call', 'addr7', 'mov', 'edi', ',', 'ebx', 'call', 'addr1', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', '8', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'call', 'addr0', 'mov', 'edi', ',', 'dword', 'ptr', '[', 'rax', ']', 'call', 'addr4', 'lea', 'rsi', ',', '[', '8253', ']', 'mov', 'edi', ',', '2', 'mov', 'rdx', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', 'addr2', 'or', 'eax', ',', '4294967295', 'jmp', 'addr5']
# ENDBR64
# PUSH RBP
# LEA RSI,[0x2004]
# MOV EDI,0x2
# PUSH RBX
# SUB RSP,0x18
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# MOV dword ptr [RSP + 0x4],0x0
# CALL 0x00001080
# LEA RSI,[RSP + 0x4]
# LEA RDI,[0x2019]
# XOR EAX,EAX
# CALL 0x00001090
# MOV EAX,dword ptr [RSP + 0x4]
# TEST EAX,EAX
# JLE 0x00001118
# MOV EBX,0x1
# LEA RBP,[0x201c]
# NOP word ptr [RAX + RAX*0x1]
# MOV RSI,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# ADD EBX,0x1
# CALL 0x00001080
# CMP dword ptr [RSP + 0x4],EBX
# JGE 0x00001100
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x00001131
# ADD RSP,0x18
# XOR EAX,EAX
# POP RBX
# POP RBP
# RET
# CALL 0x00001070
#
# 0 ['endbr64', 'push', 'rbp', 'lea', 'rsi', ',', '[', '8196', ']', 'mov', 'edi', ',', '2', 'push', 'rbx', 'sub', 'rsp', ',', '24', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'mov', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', ',', '0', 'call', '4224', 'lea', 'rsi', ',', '[', 'rsp', '+', '4', ']', 'lea', 'rdi', ',', '[', '8217', ']', 'xor', 'eax', ',', 'eax', 'call', '4240', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', 'test', 'eax', ',', 'eax', 'jle', '4376', 'mov', 'ebx', ',', '1', 'lea', 'rbp', ',', '[', '8220', ']', 'nop', 'word', 'ptr', '[', 'rax', '+', 'rax', '*', '1', ']', 'mov', 'rsi', ',', 'rbp', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'add', 'ebx', ',', '1', 'call', '4224', 'cmp', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', ',', 'ebx', 'jge', '4352', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', '4401', 'add', 'rsp', ',', '24', 'xor', 'eax', ',', 'eax', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'call', '4208']
# ENDBR64
# PUSH RBP
# LEA RSI,[0x2004]
# MOV EDI,0x2
# PUSH RBX
# SUB RSP,0x18
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# MOV dword ptr [RSP + 0x4],0x0
# CALL 0x00001080
# LEA RSI,[RSP + 0x4]
# LEA RDI,[0x2019]
# XOR EAX,EAX
# CALL 0x00001090
# MOV EAX,dword ptr [RSP + 0x4]
# TEST EAX,EAX
# JLE 0x00001118
# MOV EBX,0x1
# LEA RBP,[0x201c]
# NOP word ptr [RAX + RAX*0x1]
# MOV RSI,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# ADD EBX,0x1
# CALL 0x00001080
# CMP dword ptr [RSP + 0x4],EBX
# JGE 0x00001100
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x00001131
# ADD RSP,0x18
# XOR EAX,EAX
# POP RBX
# POP RBP
# RET
# CALL 0x00001070
#
# 1 ['endbr64', 'push', 'rbp', 'lea', 'rsi', ',', '[', 'thirteen', ']', 'mov', 'edi', ',', 'two', 'push', 'rbx', 'sub', 'rsp', ',', 'five', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'six', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', 'four', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'mov', 'dword', 'ptr', '[', 'rsp', '+', 'three', ']', ',', 'zero', 'call', 'eight', 'lea', 'rsi', ',', '[', 'rsp', '+', 'three', ']', 'lea', 'rdi', ',', '[', 'fourteen', ']', 'xor', 'eax', ',', 'eax', 'call', 'nine', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', '+', 'three', ']', 'test', 'eax', ',', 'eax', 'jle', 'eleven', 'mov', 'ebx', ',', 'one', 'lea', 'rbp', ',', '[', 'fifteen', ']', 'nop', 'word', 'ptr', '[', 'rax', '+', 'rax', '*', 'one', ']', 'mov', 'rsi', ',', 'rbp', 'mov', 'edi', ',', 'two', 'xor', 'eax', ',', 'eax', 'add', 'ebx', ',', 'one', 'call', 'eight', 'cmp', 'dword', 'ptr', '[', 'rsp', '+', 'three', ']', ',', 'ebx', 'jge', 'ten', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', 'four', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'six', ']', 'jnz', 'twelve', 'add', 'rsp', ',', 'five', 'xor', 'eax', ',', 'eax', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'call', 'seven']
# ENDBR64
# PUSH RBP
# LEA RSI,[0x2004]
# MOV EDI,0x2
# PUSH RBX
# SUB RSP,0x18
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# MOV dword ptr [RSP + 0x4],0x0
# CALL 0x00001080
# LEA RSI,[RSP + 0x4]
# LEA RDI,[0x2019]
# XOR EAX,EAX
# CALL 0x00001090
# MOV EAX,dword ptr [RSP + 0x4]
# TEST EAX,EAX
# JLE 0x00001118
# MOV EBX,0x1
# LEA RBP,[0x201c]
# NOP word ptr [RAX + RAX*0x1]
# MOV RSI,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# ADD EBX,0x1
# CALL 0x00001080
# CMP dword ptr [RSP + 0x4],EBX
# JGE 0x00001100
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x00001131
# ADD RSP,0x18
# XOR EAX,EAX
# POP RBX
# POP RBP
# RET
# CALL 0x00001070
#
# 2 ['endbr64', 'push', 'rbp', 'lea', 'rsi', ',', '[', '8196', ']', 'mov', 'edi', ',', '2', 'push', 'rbx', 'sub', 'rsp', ',', '24', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'mov', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', ',', '0', 'call', 'addr1', 'lea', 'rsi', ',', '[', 'rsp', '+', '4', ']', 'lea', 'rdi', ',', '[', '8217', ']', 'xor', 'eax', ',', 'eax', 'call', 'addr2', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', 'test', 'eax', ',', 'eax', 'jle', 'addr4', 'mov', 'ebx', ',', '1', 'lea', 'rbp', ',', '[', '8220', ']', 'nop', 'word', 'ptr', '[', 'rax', '+', 'rax', '*', '1', ']', 'mov', 'rsi', ',', 'rbp', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'add', 'ebx', ',', '1', 'call', 'addr1', 'cmp', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', ',', 'ebx', 'jge', 'addr3', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', 'addr5', 'add', 'rsp', ',', '24', 'xor', 'eax', ',', 'eax', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'call', 'addr0']
# ENDBR64
# SUB RSP,0x18
# LEA RSI,[0x2069]
# MOV EDI,0x2
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# CALL 0x00001120
# LEA RSI,[RSP + 0x4]
# LEA RDI,[0x2066]
# XOR EAX,EAX
# CALL 0x00001130
# MOV EDI,0x10
# CALL 0x00001110
# MOV EDX,dword ptr [RSP + 0x4]
# LEA RDI,[0x2082]
# MOV dword ptr [RAX],EDX
# MOV RDX,qword ptr [0x00004020]
# MOV qword ptr [0x00004020],RAX
# MOV qword ptr [RAX + 0x8],RDX
# CALL 0x000010f0
# MOV RDI,qword ptr [0x00004010]
# CALL 0x00001150
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x0000142b
# ADD RSP,0x18
# RET
# CALL 0x00001100
#
# 0 ['endbr64', 'sub', 'rsp', ',', '24', 'lea', 'rsi', ',', '[', '8297', ']', 'mov', 'edi', ',', '2', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', '4384', 'lea', 'rsi', ',', '[', 'rsp', '+', '4', ']', 'lea', 'rdi', ',', '[', '8294', ']', 'xor', 'eax', ',', 'eax', 'call', '4400', 'mov', 'edi', ',', '16', 'call', '4368', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', 'lea', 'rdi', ',', '[', '8322', ']', 'mov', 'dword', 'ptr', '[', 'rax', ']', ',', 'edx', 'mov', 'rdx', ',', 'qword', 'ptr', '[', '16416', ']', 'mov', 'qword', 'ptr', '[', '16416', ']', ',', 'rax', 'mov', 'qword', 'ptr', '[', 'rax', '+', '8', ']', ',', 'rdx', 'call', '4336', 'mov', 'rdi', ',', 'qword', 'ptr', '[', '16400', ']', 'call', '4432', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', '5163', 'add', 'rsp', ',', '24', 'ret', 'call', '4352']
# ENDBR64
# SUB RSP,0x18
# LEA RSI,[0x2069]
# MOV EDI,0x2
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# CALL 0x00001120
# LEA RSI,[RSP + 0x4]
# LEA RDI,[0x2066]
# XOR EAX,EAX
# CALL 0x00001130
# MOV EDI,0x10
# CALL 0x00001110
# MOV EDX,dword ptr [RSP + 0x4]
# LEA RDI,[0x2082]
# MOV dword ptr [RAX],EDX
# MOV RDX,qword ptr [0x00004020]
# MOV qword ptr [0x00004020],RAX
# MOV qword ptr [RAX + 0x8],RDX
# CALL 0x000010f0
# MOV RDI,qword ptr [0x00004010]
# CALL 0x00001150
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x0000142b
# ADD RSP,0x18
# RET
# CALL 0x00001100
#
# 1 ['endbr64', 'sub', 'rsp', ',', 'four', 'lea', 'rsi', ',', '[', 'fourteen', ']', 'mov', 'edi', ',', 'zero', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'five', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', 'two', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', 'nine', 'lea', 'rsi', ',', '[', 'rsp', '+', 'one', ']', 'lea', 'rdi', ',', '[', 'thirteen', ']', 'xor', 'eax', ',', 'eax', 'call', 'ten', 'mov', 'edi', ',', 'three', 'call', 'eight', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rsp', '+', 'one', ']', 'lea', 'rdi', ',', '[', 'fifteen', ']', 'mov', 'dword', 'ptr', '[', 'rax', ']', ',', 'edx', 'mov', 'rdx', ',', 'qword', 'ptr', '[', 'seventeen', ']', 'mov', 'qword', 'ptr', '[', 'seventeen', ']', ',', 'rax', 'mov', 'qword', 'ptr', '[', 'rax', '+', 'two', ']', ',', 'rdx', 'call', 'six', 'mov', 'rdi', ',', 'qword', 'ptr', '[', 'sixteen', ']', 'call', 'eleven', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', 'two', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'five', ']', 'jnz', 'twelve', 'add', 'rsp', ',', 'four', 'ret', 'call', 'seven']
# ENDBR64
# SUB RSP,0x18
# LEA RSI,[0x2069]
# MOV EDI,0x2
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# CALL 0x00001120
# LEA RSI,[RSP + 0x4]
# LEA RDI,[0x2066]
# XOR EAX,EAX
# CALL 0x00001130
# MOV EDI,0x10
# CALL 0x00001110
# MOV EDX,dword ptr [RSP + 0x4]
# LEA RDI,[0x2082]
# MOV dword ptr [RAX],EDX
# MOV RDX,qword ptr [0x00004020]
# MOV qword ptr [0x00004020],RAX
# MOV qword ptr [RAX + 0x8],RDX
# CALL 0x000010f0
# MOV RDI,qword ptr [0x00004010]
# CALL 0x00001150
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x0000142b
# ADD RSP,0x18
# RET
# CALL 0x00001100
#
# 2 ['endbr64', 'sub', 'rsp', ',', '24', 'lea', 'rsi', ',', '[', '8297', ']', 'mov', 'edi', ',', '2', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', 'addr3', 'lea', 'rsi', ',', '[', 'rsp', '+', '4', ']', 'lea', 'rdi', ',', '[', '8294', ']', 'xor', 'eax', ',', 'eax', 'call', 'addr4', 'mov', 'edi', ',', '16', 'call', 'addr2', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', 'lea', 'rdi', ',', '[', '8322', ']', 'mov', 'dword', 'ptr', '[', 'rax', ']', ',', 'edx', 'mov', 'rdx', ',', 'qword', 'ptr', '[', 'addr8', ']', 'mov', 'qword', 'ptr', '[', 'addr8', ']', ',', 'rax', 'mov', 'qword', 'ptr', '[', 'rax', '+', '8', ']', ',', 'rdx', 'call', 'addr0', 'mov', 'rdi', ',', 'qword', 'ptr', '[', 'addr7', ']', 'call', 'addr5', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', 'addr6', 'add', 'rsp', ',', '24', 'ret', 'call', 'addr1']
# ENDBR64
# SUB RSP,0x18
# LEA RSI,[0x2190]
# MOV EDI,0x2
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# CALL 0x00001090
# LEA RSI,[RSP + 0x4]
# LEA RDI,[0x249b]
# XOR EAX,EAX
# CALL 0x000010a0
# MOV EAX,dword ptr [RSP + 0x4]
# CMP EAX,0x1
# JZ 0x000013f0
# CMP EAX,0x2
# JZ 0x00001403
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x0000140a
# ADD RSP,0x18
# RET
# LEA RSI,[0x21f0]
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x00001090
# XOR EAX,EAX
# CALL 0x00001310
# CALL 0x00001080
#
# 0 ['endbr64', 'sub', 'rsp', ',', '24', 'lea', 'rsi', ',', '[', '8592', ']', 'mov', 'edi', ',', '2', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', '4240', 'lea', 'rsi', ',', '[', 'rsp', '+', '4', ']', 'lea', 'rdi', ',', '[', '9371', ']', 'xor', 'eax', ',', 'eax', 'call', '4256', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', 'cmp', 'eax', ',', '1', 'jz', '5104', 'cmp', 'eax', ',', '2', 'jz', '5123', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', '5130', 'add', 'rsp', ',', '24', 'ret', 'lea', 'rsi', ',', '[', '8688', ']', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'call', '4240', 'xor', 'eax', ',', 'eax', 'call', '4880', 'call', '4224']
# ENDBR64
# SUB RSP,0x18
# LEA RSI,[0x2190]
# MOV EDI,0x2
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# CALL 0x00001090
# LEA RSI,[RSP + 0x4]
# LEA RDI,[0x249b]
# XOR EAX,EAX
# CALL 0x000010a0
# MOV EAX,dword ptr [RSP + 0x4]
# CMP EAX,0x1
# JZ 0x000013f0
# CMP EAX,0x2
# JZ 0x00001403
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x0000140a
# ADD RSP,0x18
# RET
# LEA RSI,[0x21f0]
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x00001090
# XOR EAX,EAX
# CALL 0x00001310
# CALL 0x00001080
#
# 1 ['endbr64', 'sub', 'rsp', ',', 'four', 'lea', 'rsi', ',', '[', 'thirteen', ']', 'mov', 'edi', ',', 'one', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'five', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', 'three', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', 'seven', 'lea', 'rsi', ',', '[', 'rsp', '+', 'two', ']', 'lea', 'rdi', ',', '[', 'fifteen', ']', 'xor', 'eax', ',', 'eax', 'call', 'eight', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', '+', 'two', ']', 'cmp', 'eax', ',', 'zero', 'jz', 'ten', 'cmp', 'eax', ',', 'one', 'jz', 'eleven', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', 'three', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'five', ']', 'jnz', 'twelve', 'add', 'rsp', ',', 'four', 'ret', 'lea', 'rsi', ',', '[', 'fourteen', ']', 'mov', 'edi', ',', 'one', 'xor', 'eax', ',', 'eax', 'call', 'seven', 'xor', 'eax', ',', 'eax', 'call', 'nine', 'call', 'six']
# ENDBR64
# SUB RSP,0x18
# LEA RSI,[0x2190]
# MOV EDI,0x2
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# CALL 0x00001090
# LEA RSI,[RSP + 0x4]
# LEA RDI,[0x249b]
# XOR EAX,EAX
# CALL 0x000010a0
# MOV EAX,dword ptr [RSP + 0x4]
# CMP EAX,0x1
# JZ 0x000013f0
# CMP EAX,0x2
# JZ 0x00001403
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x0000140a
# ADD RSP,0x18
# RET
# LEA RSI,[0x21f0]
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x00001090
# XOR EAX,EAX
# CALL 0x00001310
# CALL 0x00001080
#
# 2 ['endbr64', 'sub', 'rsp', ',', '24', 'lea', 'rsi', ',', '[', '8592', ']', 'mov', 'edi', ',', '2', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'call', 'addr1', 'lea', 'rsi', ',', '[', 'rsp', '+', '4', ']', 'lea', 'rdi', ',', '[', '9371', ']', 'xor', 'eax', ',', 'eax', 'call', 'addr2', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', 'cmp', 'eax', ',', '1', 'jz', 'addr4', 'cmp', 'eax', ',', '2', 'jz', 'addr5', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', 'addr6', 'add', 'rsp', ',', '24', 'ret', 'lea', 'rsi', ',', '[', '8688', ']', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'call', 'addr1', 'xor', 'eax', ',', 'eax', 'call', 'addr3', 'call', 'addr0']
# ENDBR64
# TEST EDX,EDX
# JLE 0x000014d0
# PUSH RBP
# MOVSXD RDX,EDX
# MOV RCX,RSI
# PUSH RBX
# LEA RAX,[RDX + RDX*0x8]
# MOV RBX,RDI
# LEA RBP,[RSI + RAX*0x4]
# SUB RSP,0x8
# NOP
# MOV RSI,RBX
# MOV RDI,RCX
# MOV EDX,0x1e
# ADD RBX,0x24
# CALL 0x00001140
# MOV RCX,RAX
# MOV EAX,dword ptr [RBX + -0x4]
# ADD RCX,0x24
# MOV dword ptr [RCX + -0x4],EAX
# CMP RCX,RBP
# JNZ 0x000014a0
# ADD RSP,0x8
# POP RBX
# POP RBP
# RET
# RET
#
# 0 ['endbr64', 'test', 'edx', ',', 'edx', 'jle', '5328', 'push', 'rbp', 'movsxd', 'rdx', ',', 'edx', 'mov', 'rcx', ',', 'rsi', 'push', 'rbx', 'lea', 'rax', ',', '[', 'rdx', '+', 'rdx', '*', '8', ']', 'mov', 'rbx', ',', 'rdi', 'lea', 'rbp', ',', '[', 'rsi', '+', 'rax', '*', '4', ']', 'sub', 'rsp', ',', '8', 'nop', 'mov', 'rsi', ',', 'rbx', 'mov', 'rdi', ',', 'rcx', 'mov', 'edx', ',', '30', 'add', 'rbx', ',', '36', 'call', '4416', 'mov', 'rcx', ',', 'rax', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rbx', '+', '-', '4', ']', 'add', 'rcx', ',', '36', 'mov', 'dword', 'ptr', '[', 'rcx', '+', '-', '4', ']', ',', 'eax', 'cmp', 'rcx', ',', 'rbp', 'jnz', '5280', 'add', 'rsp', ',', '8', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'ret']
# ENDBR64
# TEST EDX,EDX
# JLE 0x000014d0
# PUSH RBP
# MOVSXD RDX,EDX
# MOV RCX,RSI
# PUSH RBX
# LEA RAX,[RDX + RDX*0x8]
# MOV RBX,RDI
# LEA RBP,[RSI + RAX*0x4]
# SUB RSP,0x8
# NOP
# MOV RSI,RBX
# MOV RDI,RCX
# MOV EDX,0x1e
# ADD RBX,0x24
# CALL 0x00001140
# MOV RCX,RAX
# MOV EAX,dword ptr [RBX + -0x4]
# ADD RCX,0x24
# MOV dword ptr [RCX + -0x4],EAX
# CMP RCX,RBP
# JNZ 0x000014a0
# ADD RSP,0x8
# POP RBX
# POP RBP
# RET
# RET
#
# 1 ['endbr64', 'test', 'edx', ',', 'edx', 'jle', 'six', 'push', 'rbp', 'movsxd', 'rdx', ',', 'edx', 'mov', 'rcx', ',', 'rsi', 'push', 'rbx', 'lea', 'rax', ',', '[', 'rdx', '+', 'rdx', '*', 'one', ']', 'mov', 'rbx', ',', 'rdi', 'lea', 'rbp', ',', '[', 'rsi', '+', 'rax', '*', 'zero', ']', 'sub', 'rsp', ',', 'one', 'nop', 'mov', 'rsi', ',', 'rbx', 'mov', 'rdi', ',', 'rcx', 'mov', 'edx', ',', 'two', 'add', 'rbx', ',', 'three', 'call', 'four', 'mov', 'rcx', ',', 'rax', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rbx', '+', '-', 'zero', ']', 'add', 'rcx', ',', 'three', 'mov', 'dword', 'ptr', '[', 'rcx', '+', '-', 'zero', ']', ',', 'eax', 'cmp', 'rcx', ',', 'rbp', 'jnz', 'five', 'add', 'rsp', ',', 'one', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'ret']
# ENDBR64
# TEST EDX,EDX
# JLE 0x000014d0
# PUSH RBP
# MOVSXD RDX,EDX
# MOV RCX,RSI
# PUSH RBX
# LEA RAX,[RDX + RDX*0x8]
# MOV RBX,RDI
# LEA RBP,[RSI + RAX*0x4]
# SUB RSP,0x8
# NOP
# MOV RSI,RBX
# MOV RDI,RCX
# MOV EDX,0x1e
# ADD RBX,0x24
# CALL 0x00001140
# MOV RCX,RAX
# MOV EAX,dword ptr [RBX + -0x4]
# ADD RCX,0x24
# MOV dword ptr [RCX + -0x4],EAX
# CMP RCX,RBP
# JNZ 0x000014a0
# ADD RSP,0x8
# POP RBX
# POP RBP
# RET
# RET
#
# 2 ['endbr64', 'test', 'edx', ',', 'edx', 'jle', 'addr2', 'push', 'rbp', 'movsxd', 'rdx', ',', 'edx', 'mov', 'rcx', ',', 'rsi', 'push', 'rbx', 'lea', 'rax', ',', '[', 'rdx', '+', 'rdx', '*', '8', ']', 'mov', 'rbx', ',', 'rdi', 'lea', 'rbp', ',', '[', 'rsi', '+', 'rax', '*', '4', ']', 'sub', 'rsp', ',', '8', 'nop', 'mov', 'rsi', ',', 'rbx', 'mov', 'rdi', ',', 'rcx', 'mov', 'edx', ',', '30', 'add', 'rbx', ',', '36', 'call', 'addr0', 'mov', 'rcx', ',', 'rax', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rbx', '+', '-', '4', ']', 'add', 'rcx', ',', '36', 'mov', 'dword', 'ptr', '[', 'rcx', '+', '-', '4', ']', ',', 'eax', 'cmp', 'rcx', ',', 'rbp', 'jnz', 'addr1', 'add', 'rsp', ',', '8', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'ret']
# ENDBR64
# PUSH RBP
# MOV EBP,ESI
# PUSH RBX
# MOV RBX,RDI
# SUB RSP,0x8
# MOV RAX,qword ptr [RDI]
# TEST RAX,RAX
# JZ 0x00002186
# NOP word ptr [RAX + RAX*0x1]
# LEA RBX,[RAX + 0x10]
# CMP dword ptr [RAX],EBP
# JL 0x0000217e
# JLE 0x0000219d
# LEA RBX,[RAX + 0x8]
# MOV RAX,qword ptr [RBX]
# TEST RAX,RAX
# JNZ 0x00002170
# MOV EDI,0x18
# CALL 0x000010d0
# PXOR XMM0,XMM0
# MOV dword ptr [RAX],EBP
# MOVUPS xmmword ptr [RAX + 0x8],XMM0
# MOV qword ptr [RBX],RAX
# ADD RSP,0x8
# POP RBX
# POP RBP
# RET
#
# ...
# JS 0x00001448
# MOV EBP,EDI
# XOR EBX,EBX
# NOP word ptr [RAX + RAX*0x1]
# MOV EDI,0x20
# ADD EBX,0x1
# CALL 0x000010a0
# CMP EBP,EBX
# JGE 0x00001428
# ADD RSP,0x8
# MOV EAX,EBX
# POP RBX
# POP RBP
# RET
# XOR EBX,EBX
# ADD RSP,0x8
# MOV EAX,EBX
# POP RBX
# POP RBP
# RET
#
# 0 ['endbr64', 'push', 'rbp', 'push', 'rbx', 'sub', 'rsp', ',', '8', 'test', 'edi', ',', 'edi', 'js', '5192', 'mov', 'ebp', ',', 'edi', 'xor', 'ebx', ',', 'ebx', 'nop', 'word', 'ptr', '[', 'rax', '+', 'rax', '*', '1', ']', 'mov', 'edi', ',', '32', 'add', 'ebx', ',', '1', 'call', '4256', 'cmp', 'ebp', ',', 'ebx', 'jge', '5160', 'add', 'rsp', ',', '8', 'mov', 'eax', ',', 'ebx', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'xor', 'ebx', ',', 'ebx', 'add', 'rsp', ',', '8', 'mov', 'eax', ',', 'ebx', 'pop', 'rbx', 'pop', 'rbp', 'ret']
# ENDBR64
# PUSH RBP
# PUSH RBX
# SUB RSP,0x8
# TEST EDI,EDI
# JS 0x00001448
# MOV EBP,EDI
# XOR EBX,EBX
# NOP word ptr [RAX + RAX*0x1]
# MOV EDI,0x20
# ADD EBX,0x1
# CALL 0x000010a0
# CMP EBP,EBX
# JGE 0x00001428
# ADD RSP,0x8
# MOV EAX,EBX
# POP RBX
# POP RBP
# RET
# XOR EBX,EBX
# ADD RSP,0x8
# MOV EAX,EBX
# POP RBX
# POP RBP
# RET
#
# 1 ['endbr64', 'push', 'rbp', 'push', 'rbx', 'sub', 'rsp', ',', 'one', 'test', 'edi', ',', 'edi', 'js', 'five', 'mov', 'ebp', ',', 'edi', 'xor', 'ebx', ',', 'ebx', 'nop', 'word', 'ptr', '[', 'rax', '+', 'rax', '*', 'zero', ']', 'mov', 'edi', ',', 'two', 'add', 'ebx', ',', 'zero', 'call', 'three', 'cmp', 'ebp', ',', 'ebx', 'jge', 'four', 'add', 'rsp', ',', 'one', 'mov', 'eax', ',', 'ebx', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'xor', 'ebx', ',', 'ebx', 'add', 'rsp', ',', 'one', 'mov', 'eax', ',', 'ebx', 'pop', 'rbx', 'pop', 'rbp', 'ret']
# ENDBR64
# PUSH RBP
# PUSH RBX
# SUB RSP,0x8
# TEST EDI,EDI
# JS 0x00001448
# MOV EBP,EDI
# XOR EBX,EBX
# NOP word ptr [RAX + RAX*0x1]
# MOV EDI,0x20
# ADD EBX,0x1
# CALL 0x000010a0
# CMP EBP,EBX
# JGE 0x00001428
# ADD RSP,0x8
# MOV EAX,EBX
# POP RBX
# POP RBP
# RET
# XOR EBX,EBX
# ADD RSP,0x8
# MOV EAX,EBX
# POP RBX
# POP RBP
# RET
#
# 2 ['endbr64', 'push', 'rbp', 'push', 'rbx', 'sub', 'rsp', ',', '8', 'test', 'edi', ',', 'edi', 'js', 'addr2', 'mov', 'ebp', ',', 'edi', 'xor', 'ebx', ',', 'ebx', 'nop', 'word', 'ptr', '[', 'rax', '+', 'rax', '*', '1', ']', 'mov', 'edi', ',', '32', 'add', 'ebx', ',', '1', 'call', 'addr0', 'cmp', 'ebp', ',', 'ebx', 'jge', 'addr1', 'add', 'rsp', ',', '8', 'mov', 'eax', ',', 'ebx', 'pop', 'rbx', 'pop', 'rbp', 'ret', 'xor', 'ebx', ',', 'ebx', 'add', 'rsp', ',', '8', 'mov', 'eax', ',', 'ebx', 'pop', 'rbx', 'pop', 'rbp', 'ret']
# ENDBR64
# TEST RDI,RDI
# JZ 0x00001560
# PUSH RBP
# LEA RBP,[0x2004]
# PUSH RBX
# MOV RBX,RDI
# SUB RSP,0x8
# NOP dword ptr [RAX]
# MOV EDX,dword ptr [RBX]
# MOV RSI,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x000010d0
# MOV RBX,qword ptr [RBX + 0x10]
# TEST RBX,RBX
# JNZ 0x00001530
# ADD RSP,0x8
# MOV EDI,0xa
# POP RBX
# POP RBP
# JMP 0x000010a0
# MOV EDI,0xa
# JMP 0x000010a0
#
# 0 ['endbr64', 'test', 'rdi', ',', 'rdi', 'jz', '5472', 'push', 'rbp', 'lea', 'rbp', ',', '[', '8196', ']', 'push', 'rbx', 'mov', 'rbx', ',', 'rdi', 'sub', 'rsp', ',', '8', 'nop', 'dword', 'ptr', '[', 'rax', ']', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rbx', ']', 'mov', 'rsi', ',', 'rbp', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'call', '4304', 'mov', 'rbx', ',', 'qword', 'ptr', '[', 'rbx', '+', '16', ']', 'test', 'rbx', ',', 'rbx', 'jnz', '5424', 'add', 'rsp', ',', '8', 'mov', 'edi', ',', '10', 'pop', 'rbx', 'pop', 'rbp', 'jmp', '4256', 'mov', 'edi', ',', '10', 'jmp', '4256']
# ENDBR64
# TEST RDI,RDI
# JZ 0x00001560
# PUSH RBP
# LEA RBP,[0x2004]
# PUSH RBX
# MOV RBX,RDI
# SUB RSP,0x8
# NOP dword ptr [RAX]
# MOV EDX,dword ptr [RBX]
# MOV RSI,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x000010d0
# MOV RBX,qword ptr [RBX + 0x10]
# TEST RBX,RBX
# JNZ 0x00001530
# ADD RSP,0x8
# MOV EDI,0xa
# POP RBX
# POP RBP
# JMP 0x000010a0
# MOV EDI,0xa
# JMP 0x000010a0
#
# 1 ['endbr64', 'test', 'rdi', ',', 'rdi', 'jz', 'seven', 'push', 'rbp', 'lea', 'rbp', ',', '[', 'eight', ']', 'push', 'rbx', 'mov', 'rbx', ',', 'rdi', 'sub', 'rsp', ',', 'one', 'nop', 'dword', 'ptr', '[', 'rax', ']', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rbx', ']', 'mov', 'rsi', ',', 'rbp', 'mov', 'edi', ',', 'zero', 'xor', 'eax', ',', 'eax', 'call', 'five', 'mov', 'rbx', ',', 'qword', 'ptr', '[', 'rbx', '+', 'three', ']', 'test', 'rbx', ',', 'rbx', 'jnz', 'six', 'add', 'rsp', ',', 'one', 'mov', 'edi', ',', 'two', 'pop', 'rbx', 'pop', 'rbp', 'jmp', 'four', 'mov', 'edi', ',', 'two', 'jmp', 'four']
# ENDBR64
# TEST RDI,RDI
# JZ 0x00001560
# PUSH RBP
# LEA RBP,[0x2004]
# PUSH RBX
# MOV RBX,RDI
# SUB RSP,0x8
# NOP dword ptr [RAX]
# MOV EDX,dword ptr [RBX]
# MOV RSI,RBP
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x000010d0
# MOV RBX,qword ptr [RBX + 0x10]
# TEST RBX,RBX
# JNZ 0x00001530
# ADD RSP,0x8
# MOV EDI,0xa
# POP RBX
# POP RBP
# JMP 0x000010a0
# MOV EDI,0xa
# JMP 0x000010a0
#
# 2 ['endbr64', 'test', 'rdi', ',', 'rdi', 'jz', 'addr3', 'push', 'rbp', 'lea', 'rbp', ',', '[', '8196', ']', 'push', 'rbx', 'mov', 'rbx', ',', 'rdi', 'sub', 'rsp', ',', '8', 'nop', 'dword', 'ptr', '[', 'rax', ']', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rbx', ']', 'mov', 'rsi', ',', 'rbp', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'call', 'addr1', 'mov', 'rbx', ',', 'qword', 'ptr', '[', 'rbx', '+', '16', ']', 'test', 'rbx', ',', 'rbx', 'jnz', 'addr2', 'add', 'rsp', ',', '8', 'mov', 'edi', ',', '10', 'pop', 'rbx', 'pop', 'rbp', 'jmp', 'addr0', 'mov', 'edi', ',', '10', 'jmp', 'addr0']
# ENDBR64
# SUB RSP,0x8
# MOV EAX,dword ptr [0x00004010]
# MOV ECX,dword ptr [0x00004014]
# MOV ESI,EAX
# SUB ESI,ECX
# CMP ESI,0x4
# JZ 0x00001378
# MOV EDX,EDI
# CMP ECX,-0x1
# JNZ 0x0000133e
# MOV dword ptr [0x00004014],0x0
# ADD EAX,0x1
# LEA RCX,[0x4030]
# MOV EDI,0x2
# MOV dword ptr [0x00004010],EAX
# CDQE
# LEA RSI,[0x2058]
# MOV dword ptr [RCX + RAX*0x4],EDX
# XOR EAX,EAX
# CALL 0x00001090
# XOR EAX,EAX
# ADD RSP,0x8
# JMP 0x00001280
# LEA RDI,[0x200c]
# CALL 0x00001080
# XOR EAX,EAX
# ADD RSP,0x8
# JMP 0x00001280
#
# 0 ['endbr64', 'sub', 'rsp', ',', '8', 'mov', 'eax', ',', 'dword', 'ptr', '[', '16400', ']', 'mov', 'ecx', ',', 'dword', 'ptr', '[', '16404', ']', 'mov', 'esi', ',', 'eax', 'sub', 'esi', ',', 'ecx', 'cmp', 'esi', ',', '4', 'jz', '4984', 'mov', 'edx', ',', 'edi', 'cmp', 'ecx', ',', '-', '1', 'jnz', '4926', 'mov', 'dword', 'ptr', '[', '16404', ']', ',', '0', 'add', 'eax', ',', '1', 'lea', 'rcx', ',', '[', '16432', ']', 'mov', 'edi', ',', '2', 'mov', 'dword', 'ptr', '[', '16400', ']', ',', 'eax', 'cdqe', 'lea', 'rsi', ',', '[', '8280', ']', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rax', '*', '4', ']', ',', 'edx', 'xor', 'eax', ',', 'eax', 'call', '4240', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', '8', 'jmp', '4736', 'lea', 'rdi', ',', '[', '8204', ']', 'call', '4224', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', '8', 'jmp', '4736']
# ENDBR64
# SUB RSP,0x8
# MOV EAX,dword ptr [0x00004010]
# MOV ECX,dword ptr [0x00004014]
# MOV ESI,EAX
# SUB ESI,ECX
# CMP ESI,0x4
# JZ 0x00001378
# MOV EDX,EDI
# CMP ECX,-0x1
# JNZ 0x0000133e
# MOV dword ptr [0x00004014],0x0
# ADD EAX,0x1
# LEA RCX,[0x4030]
# MOV EDI,0x2
# MOV dword ptr [0x00004010],EAX
# CDQE
# LEA RSI,[0x2058]
# MOV dword ptr [RCX + RAX*0x4],EDX
# XOR EAX,EAX
# CALL 0x00001090
# XOR EAX,EAX
# ADD RSP,0x8
# JMP 0x00001280
# LEA RDI,[0x200c]
# CALL 0x00001080
# XOR EAX,EAX
# ADD RSP,0x8
# JMP 0x00001280
#
# 1 ['endbr64', 'sub', 'rsp', ',', 'four', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'twelve', ']', 'mov', 'ecx', ',', 'dword', 'ptr', '[', 'thirteen', ']', 'mov', 'esi', ',', 'eax', 'sub', 'esi', ',', 'ecx', 'cmp', 'esi', ',', 'three', 'jz', 'nine', 'mov', 'edx', ',', 'edi', 'cmp', 'ecx', ',', '-', 'one', 'jnz', 'eight', 'mov', 'dword', 'ptr', '[', 'thirteen', ']', ',', 'zero', 'add', 'eax', ',', 'one', 'lea', 'rcx', ',', '[', 'fourteen', ']', 'mov', 'edi', ',', 'two', 'mov', 'dword', 'ptr', '[', 'twelve', ']', ',', 'eax', 'cdqe', 'lea', 'rsi', ',', '[', 'eleven', ']', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rax', '*', 'three', ']', ',', 'edx', 'xor', 'eax', ',', 'eax', 'call', 'six', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', 'four', 'jmp', 'seven', 'lea', 'rdi', ',', '[', 'ten', ']', 'call', 'five', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', 'four', 'jmp', 'seven']
# ENDBR64
# SUB RSP,0x8
# MOV EAX,dword ptr [0x00004010]
# MOV ECX,dword ptr [0x00004014]
# MOV ESI,EAX
# SUB ESI,ECX
# CMP ESI,0x4
# JZ 0x00001378
# MOV EDX,EDI
# CMP ECX,-0x1
# JNZ 0x0000133e
# MOV dword ptr [0x00004014],0x0
# ADD EAX,0x1
# LEA RCX,[0x4030]
# MOV EDI,0x2
# MOV dword ptr [0x00004010],EAX
# CDQE
# LEA RSI,[0x2058]
# MOV dword ptr [RCX + RAX*0x4],EDX
# XOR EAX,EAX
# CALL 0x00001090
# XOR EAX,EAX
# ADD RSP,0x8
# JMP 0x00001280
# LEA RDI,[0x200c]
# CALL 0x00001080
# XOR EAX,EAX
# ADD RSP,0x8
# JMP 0x00001280
#
# 2 ['endbr64', 'sub', 'rsp', ',', '8', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'addr5', ']', 'mov', 'ecx', ',', 'dword', 'ptr', '[', 'addr6', ']', 'mov', 'esi', ',', 'eax', 'sub', 'esi', ',', 'ecx', 'cmp', 'esi', ',', '4', 'jz', 'addr4', 'mov', 'edx', ',', 'edi', 'cmp', 'ecx', ',', '-', '1', 'jnz', 'addr3', 'mov', 'dword', 'ptr', '[', 'addr6', ']', ',', '0', 'add', 'eax', ',', '1', 'lea', 'rcx', ',', '[', '16432', ']', 'mov', 'edi', ',', '2', 'mov', 'dword', 'ptr', '[', 'addr5', ']', ',', 'eax', 'cdqe', 'lea', 'rsi', ',', '[', '8280', ']', 'mov', 'dword', 'ptr', '[', 'rcx', '+', 'rax', '*', '4', ']', ',', 'edx', 'xor', 'eax', ',', 'eax', 'call', 'addr1', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', '8', 'jmp', 'addr2', 'lea', 'rdi', ',', '[', '8204', ']', 'call', 'addr0', 'xor', 'eax', ',', 'eax', 'add', 'rsp', ',', '8', 'jmp', 'addr2']
# ENDBR64
# PUSH RBX
# LEA RSI,[0x2004]
# MOV EDI,0x2
# LEA RBX,[0x2043]
# SUB RSP,0x10
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# MOV dword ptr [RSP],0x0
# MOV dword ptr [RSP + 0x4],0x0
# CALL 0x00001080
# MOV RSI,RSP
# MOV RDI,RBX
# XOR EAX,EAX
# CALL 0x00001090
# LEA RSI,[0x201c]
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x00001080
# LEA RSI,[RSP + 0x4]
# MOV RDI,RBX
# XOR EAX,EAX
# CALL 0x00001090
# MOV EAX,dword ptr [RSP]
# MOV EDX,dword ptr [RSP + 0x4]
# LEA RSI,[0x2035]
# MOV EDI,0x2
# CMP EDX,EAX
# CMOVL EDX,EAX
# XOR EAX,EAX
# CALL 0x00001080
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x00001146
# ADD RSP,0x10
# XOR EAX,EAX
# POP RBX
# RET
# CALL 0x00001070
#
# 0 ['endbr64', 'push', 'rbx', 'lea', 'rsi', ',', '[', '8196', ']', 'mov', 'edi', ',', '2', 'lea', 'rbx', ',', '[', '8259', ']', 'sub', 'rsp', ',', '16', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'mov', 'dword', 'ptr', '[', 'rsp', ']', ',', '0', 'mov', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', ',', '0', 'call', '4224', 'mov', 'rsi', ',', 'rsp', 'mov', 'rdi', ',', 'rbx', 'xor', 'eax', ',', 'eax', 'call', '4240', 'lea', 'rsi', ',', '[', '8220', ']', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'call', '4224', 'lea', 'rsi', ',', '[', 'rsp', '+', '4', ']', 'mov', 'rdi', ',', 'rbx', 'xor', 'eax', ',', 'eax', 'call', '4240', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', ']', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', 'lea', 'rsi', ',', '[', '8245', ']', 'mov', 'edi', ',', '2', 'cmp', 'edx', ',', 'eax', 'cmovl', 'edx', ',', 'eax', 'xor', 'eax', ',', 'eax', 'call', '4224', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', '4422', 'add', 'rsp', ',', '16', 'xor', 'eax', ',', 'eax', 'pop', 'rbx', 'ret', 'call', '4208']
# ENDBR64
# PUSH RBX
# LEA RSI,[0x2004]
# MOV EDI,0x2
# LEA RBX,[0x2043]
# SUB RSP,0x10
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# MOV dword ptr [RSP],0x0
# MOV dword ptr [RSP + 0x4],0x0
# CALL 0x00001080
# MOV RSI,RSP
# MOV RDI,RBX
# XOR EAX,EAX
# CALL 0x00001090
# LEA RSI,[0x201c]
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x00001080
# LEA RSI,[RSP + 0x4]
# MOV RDI,RBX
# XOR EAX,EAX
# CALL 0x00001090
# MOV EAX,dword ptr [RSP]
# MOV EDX,dword ptr [RSP + 0x4]
# LEA RSI,[0x2035]
# MOV EDI,0x2
# CMP EDX,EAX
# CMOVL EDX,EAX
# XOR EAX,EAX
# CALL 0x00001080
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x00001146
# ADD RSP,0x10
# XOR EAX,EAX
# POP RBX
# RET
# CALL 0x00001070
#
# 1 ['endbr64', 'push', 'rbx', 'lea', 'rsi', ',', '[', 'ten', ']', 'mov', 'edi', ',', 'one', 'lea', 'rbx', ',', '[', 'thirteen', ']', 'sub', 'rsp', ',', 'four', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'five', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', 'three', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'mov', 'dword', 'ptr', '[', 'rsp', ']', ',', 'zero', 'mov', 'dword', 'ptr', '[', 'rsp', '+', 'two', ']', ',', 'zero', 'call', 'seven', 'mov', 'rsi', ',', 'rsp', 'mov', 'rdi', ',', 'rbx', 'xor', 'eax', ',', 'eax', 'call', 'eight', 'lea', 'rsi', ',', '[', 'eleven', ']', 'mov', 'edi', ',', 'one', 'xor', 'eax', ',', 'eax', 'call', 'seven', 'lea', 'rsi', ',', '[', 'rsp', '+', 'two', ']', 'mov', 'rdi', ',', 'rbx', 'xor', 'eax', ',', 'eax', 'call', 'eight', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', ']', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rsp', '+', 'two', ']', 'lea', 'rsi', ',', '[', 'twelve', ']', 'mov', 'edi', ',', 'one', 'cmp', 'edx', ',', 'eax', 'cmovl', 'edx', ',', 'eax', 'xor', 'eax', ',', 'eax', 'call', 'seven', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', 'three', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', 'five', ']', 'jnz', 'nine', 'add', 'rsp', ',', 'four', 'xor', 'eax', ',', 'eax', 'pop', 'rbx', 'ret', 'call', 'six']
# ENDBR64
# PUSH RBX
# LEA RSI,[0x2004]
# MOV EDI,0x2
# LEA RBX,[0x2043]
# SUB RSP,0x10
# MOV RAX,qword ptr FS:[0x28]
# MOV qword ptr [RSP + 0x8],RAX
# XOR EAX,EAX
# MOV dword ptr [RSP],0x0
# MOV dword ptr [RSP + 0x4],0x0
# CALL 0x00001080
# MOV RSI,RSP
# MOV RDI,RBX
# XOR EAX,EAX
# CALL 0x00001090
# LEA RSI,[0x201c]
# MOV EDI,0x2
# XOR EAX,EAX
# CALL 0x00001080
# LEA RSI,[RSP + 0x4]
# MOV RDI,RBX
# XOR EAX,EAX
# CALL 0x00001090
# MOV EAX,dword ptr [RSP]
# MOV EDX,dword ptr [RSP + 0x4]
# LEA RSI,[0x2035]
# MOV EDI,0x2
# CMP EDX,EAX
# CMOVL EDX,EAX
# XOR EAX,EAX
# CALL 0x00001080
# MOV RAX,qword ptr [RSP + 0x8]
# SUB RAX,qword ptr FS:[0x28]
# JNZ 0x00001146
# ADD RSP,0x10
# XOR EAX,EAX
# POP RBX
# RET
# CALL 0x00001070
#
# 2 ['endbr64', 'push', 'rbx', 'lea', 'rsi', ',', '[', '8196', ']', 'mov', 'edi', ',', '2', 'lea', 'rbx', ',', '[', '8259', ']', 'sub', 'rsp', ',', '16', 'mov', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'mov', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', ',', 'rax', 'xor', 'eax', ',', 'eax', 'mov', 'dword', 'ptr', '[', 'rsp', ']', ',', '0', 'mov', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', ',', '0', 'call', 'addr1', 'mov', 'rsi', ',', 'rsp', 'mov', 'rdi', ',', 'rbx', 'xor', 'eax', ',', 'eax', 'call', 'addr2', 'lea', 'rsi', ',', '[', '8220', ']', 'mov', 'edi', ',', '2', 'xor', 'eax', ',', 'eax', 'call', 'addr1', 'lea', 'rsi', ',', '[', 'rsp', '+', '4', ']', 'mov', 'rdi', ',', 'rbx', 'xor', 'eax', ',', 'eax', 'call', 'addr2', 'mov', 'eax', ',', 'dword', 'ptr', '[', 'rsp', ']', 'mov', 'edx', ',', 'dword', 'ptr', '[', 'rsp', '+', '4', ']', 'lea', 'rsi', ',', '[', '8245', ']', 'mov', 'edi', ',', '2', 'cmp', 'edx', ',', 'eax', 'cmovl', 'edx', ',', 'eax', 'xor', 'eax', ',', 'eax', 'call', 'addr1', 'mov', 'rax', ',', 'qword', 'ptr', '[', 'rsp', '+', '8', ']', 'sub', 'rax', ',', 'qword', 'ptr', 'fs', ':', '[', '40', ']', 'jnz', 'addr3', 'add', 'rsp', ',', '16', 'xor', 'eax', ',', 'eax', 'pop', 'rbx', 'ret', 'call', 'addr0']
# ENDBR64
# TEST ESI,ESI
# JNZ 0x00003018
# MOV ESI,dword ptr [RDI + 0x10]
# TEST ESI,ESI
# JNZ 0x00003010
# MOVQ XMM0,RDX
# PUNPCKLQDQ XMM0,XMM0
# MOVUPS xmmword ptr [RDI],XMM0
# RET
# MOV qword ptr [RDI + 0x8],RDX
# RET
# CMP ESI,0x1
# JZ 0x00003027
# CMP ESI,0x2
# JZ 0x00003040
# CMP ESI,0x3
# JNZ 0x00003030
# RET
# LEA RDI,[0x6258]
# JMP 0x00001170
# MOV ECX,dword ptr [RDI + 0x10]
# TEST ECX,ECX
# JZ 0x00002fff
# MOV qword ptr [RDI],RDX
# RET
#
# 0 ['endbr64', 'test', 'esi', ',', 'esi', 'jnz', '12312', 'mov', 'esi', ',', 'dword', 'ptr', '[', 'rdi', '+', '16', ']', 'test', 'esi', ',', 'esi', 'jnz', '12304', 'movq', 'xmm0', ',', 'rdx', 'punpcklqdq', 'xmm0', ',', 'xmm0', 'movups', 'xmmword', 'ptr', '[', 'rdi', ']', ',', 'xmm0', 'ret', 'mov', 'qword', 'ptr', '[', 'rdi', '+', '8', ']', ',', 'rdx', 'ret', 'cmp', 'esi', ',', '1', 'jz', '12327', 'cmp', 'esi', ',', '2', 'jz', '12352', 'cmp', 'esi', ',', '3', 'jnz', '12336', 'ret', 'lea', 'rdi', ',', '[', '25176', ']', 'jmp', '4464', 'mov', 'ecx', ',', 'dword', 'ptr', '[', 'rdi', '+', '16', ']', 'test', 'ecx', ',', 'ecx', 'jz', '12287', 'mov', 'qword', 'ptr', '[', 'rdi', ']', ',', 'rdx', 'ret']

# %%
print(tokenizer.pad_token)
# Out:
# [PAD]

# %%
tokenizer.save_pretrained("./../models/bert_pretokenizer_trained")
# Out:
# ('./../models/bert_pretokenizer_trained/tokenizer_config.json',
#  './../models/bert_pretokenizer_trained/special_tokens_map.json',
#  './../models/bert_pretokenizer_trained/vocab.txt',
#  './../models/bert_pretokenizer_trained/added_tokens.json',
#  './../models/bert_pretokenizer_trained/tokenizer.json')
